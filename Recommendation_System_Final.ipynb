# %% [markdown]
# # Recommendation System

# %%
import pandas as pd
import numpy as np
import nltk
from nltk.corpus import stopwords
from nltk.corpus import wordnet
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.stem.wordnet import WordNetLemmatizer 
from rake_nltk import Rake
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Wine Recommendation based on Description

# %% [markdown]
# Wine with similar descriptions will be recommended given a description of certain wine

# %%
# Import wine dataset with wine titles
df = pd.read_csv('winemag-data-130k-v2.csv')

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# 1                  NaN                NaN          Roger Voss
# 2    Willamette Valley  Willamette Valley        Paul Gregutt
# 3  Lake Michigan Shore                NaN  Alexander Peartree
# 4    Willamette Valley  Willamette Valley        Paul Gregutt
#
#   taster_twitter_handle                                              title  \
# 0          @kerinokeefe                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1            @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2           @paulgwine       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3                   NaN  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4           @paulgwine   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#
#           variety               winery
# 0     White Blend              Nicosia
# 1  Portuguese Red  Quinta dos Avidagos
# 2      Pinot Gris            Rainstorm
# 3        Riesling           St. Julian
# 4      Pinot Noir         Sweet Cheeks

# %% [markdown]
# Use Rake to extract key words for the description

# %%
sentence_lst = []

for index, row in df.iterrows():
    des = row['description']
    # instantiating Rake (English stopwords from NLTK and discards all puntuation characters)
    r = Rake()
    # extracting the words by passing the text
    r.extract_keywords_from_text(des)
    # getting the dictionary whith key words as keys and their scores as values
    key_words_dict_scores = r.get_word_degrees()
    # assigning the key words to the new column for the corresponding movie
    sentence_lst.append(list(key_words_dict_scores.keys()))

# %% [markdown]
# Tag words using nltk.pos_tag

# %%
taggedList = []
for sentence in sentence_lst:
    sentList = nltk.sent_tokenize(' '.join(sentence))
    txt_list = nltk.word_tokenize(sentList[0])
    tagged_sentence = nltk.pos_tag(txt_list)
    taggedList.append(tagged_sentence)

# %%
taggedList
# Out:
# [[('citrus', 'NN'),
#   ('overly', 'RB'),
#   ('expressive', 'JJ'),
#   ('dried', 'VBD'),
#   ('herb', 'NN'),
#   ('brimstone', 'NN'),
#   ('broom', 'NN'),
#   ('offering', 'NN'),
#   ('unripened', 'JJ'),
#   ('apple', 'NN'),
#   ('sage', 'NN'),
#   ('alongside', 'RB'),
#   ('brisk', 'JJ'),
#   ('acidity', 'NN'),
#   ('aromas', 'VBP'),
#   ('include', 'VBP'),
#   ('tropical', 'JJ'),
#   ('fruit', 'NN'),
#   ('palate', 'NN')],
#  [('fruity', 'NN'),
#   ('still', 'RB'),
#   ('structured', 'VBD'),
#   ('juicy', 'NN'),
#   ('red', 'JJ'),
#   ('berry', 'NN'),
#   ('fruits', 'NNS'),
#   ('already', 'RB'),
#   ('drinkable', 'JJ'),
#   ('better', 'JJR'),
#   ('filled', 'VBN'),
#   ('ripe', 'NN'),
#   ('certainly', 'RB'),
#   ('wine', 'VBZ'),
#   ('although', 'IN'),
#   ('2016', 'CD'),
#   ('freshened', 'VBD'),
#   ('acidity', 'NN'),
#   ('smooth', 'JJ'),
#   ('firm', 'NN'),
#   ('tannins', 'NNS')],
#  [('flavors', 'NNS'),
#   ('lime', 'VBP'),
#   ('flesh', 'JJ'),
#   ('crisp', 'NN'),
#   ('acidity', 'NN'),
#   ('underscoring', 'VBG'),
#   ('tart', 'JJ'),
#   ('stainless', 'NN'),
#   ('rind', 'NN'),
#   ('dominate', 'JJ'),
#   ('wine', 'NN'),
#   ('steel', 'NN'),
#   ('fermented', 'VBD'),
#   ('green', 'JJ'),
#   ('pineapple', 'NN'),
#   ('pokes', 'NNS'),
#   ('snappy', 'JJ')],
#  [('drizzled', 'VBN'),
#   ('guava', 'NN'),
#   ('semidry', 'JJ'),
#   ('finish', 'JJ'),
#   ('notes', 'NNS'),
#   ('orange', 'VBP'),
#   ('blossom', 'JJ'),
#   ('start', 'NN'),
#   ('honey', 'NN'),
#   ('mango', 'NN'),
#   ('giving', 'VBG'),
#   ('way', 'NN'),
#   ('opulent', 'JJ'),
#   ('slightly', 'RB'),
#   ('astringent', 'JJ'),
#   ('lemon', 'NN'),
#   ('pith', 'NN'),
#   ('bit', 'NN'),
#   ('pineapple', 'JJ'),
#   ('rind', 'NN'),
#   ('aromas', 'NN'),
#   ('palate', 'NN')],
#  [('earthy', 'JJ'),
#   ('rustic', 'JJ'),
#   ('2012', 'CD'),
#   ('pleasantly', 'RB'),
#   ('unfussy', 'JJ'),
#   ('country', 'NN'),
#   ('wine', 'NN'),
#   ('rather', 'RB'),
#   ('rough', 'JJ'),
#   ('herbal', 'JJ'),
#   ('characteristics', 'NNS'),
#   ('good', 'JJ'),
#   ('companion', 'NN'),
#   ('comes', 'VBZ'),
#   ('across', 'IN'),
#   ('regular', 'JJ'),
#   ('bottling', 'VBG'),
#   ('much', 'JJ'),
#   ('like', 'IN'),
#   ('nonetheless', 'RB'),
#   ('hearty', 'JJ'),
#   ('winter', 'NN'),
#   ('stew', 'NN'),
#   ('think', 'VBP'),
#   ('tannic', 'NN')],
#  [('fresh', 'JJ'),
#   ('case', 'NN'),
#   ('herbal', 'JJ'),
#   ('flavors', 'NNS'),
#   ('complement', 'VBP'),
#   ('dark', 'JJ'),
#   ('plum', 'NN'),
#   ('fruit', 'NN'),
#   ('finish', 'JJ'),
#   ('blackberry', 'NN'),
#   ('mouth', 'NN'),
#   ('spicy', 'NN'),
#   ('grabby', 'NN'),
#   ('typical', 'JJ'),
#   ('navarran', 'NN'),
#   ('whiff', 'NN'),
#   ('raspberry', 'VBP'),
#   ('aromas', 'VB'),
#   ('show', 'NN'),
#   ('fairly', 'RB'),
#   ('full', 'JJ'),
#   ('bodied', 'VBD'),
#   ('tomatoey', 'JJ'),
#   ('acidity', 'NN'),
#   ('horseradish', 'NN'),
#   ('green', 'JJ'),
#   ('herbs', 'NN')],
#  [('candied', 'VBN'),
#   ('berry', 'NN'),
#   ('soft', 'JJ'),
#   ('tannins', 'NNS'),
#   ('bright', 'JJ'),
#   ('carry', 'VBP'),
#   ('balanced', 'VBN'),
#   ('white', 'JJ'),
#   ('pepper', 'NN'),
#   ('informal', 'NN'),
#   ('red', 'JJ'),
#   ('savory', 'NN'),
#   ('herb', 'NN'),
#   ('fresh', 'JJ'),
#   ('acidity', 'NN'),
#   ('opens', 'VBZ'),
#   ('aromas', 'JJ'),
#   ('palate', 'NN')],
#  [('profusion', 'NN'),
#   ('much', 'RB'),
#   ('food', 'NN'),
#   ('balanced', 'VBD'),
#   ('firm', 'JJ'),
#   ('texture', 'NN'),
#   ('acidity', 'NN'),
#   ('dry', 'NN'),
#   ('restrained', 'VBD'),
#   ('wine', 'JJ'),
#   ('offers', 'NNS'),
#   ('spice', 'NN')],
#  [('fruity', 'NN'),
#   ('fresh', 'JJ'),
#   ('savory', 'NN'),
#   ('dried', 'VBN'),
#   ('thyme', 'JJ'),
#   ('notes', 'NNS'),
#   ('accent', 'JJ'),
#   ('sunnier', 'JJR'),
#   ('flavors', 'NNS'),
#   ('elegant', 'VBP'),
#   ('preserved', 'VBN'),
#   ('peach', 'NN'),
#   ('sprightly', 'RB'),
#   ('footprint', 'JJ'),
#   ('dry', 'JJ'),
#   ('wine', 'NN'),
#   ('brisk', 'NN')],
#  [('great', 'JJ'),
#   ('depth', 'NN'),
#   ('touch', 'JJ'),
#   ('fresh', 'JJ'),
#   ('apple', 'NN'),
#   ('balanced', 'VBD'),
#   ('pear', 'JJ'),
#   ('fruits', 'NNS'),
#   ('crisp', 'VBP'),
#   ('texture', 'NN'),
#   ('flavor', 'NN'),
#   ('drink', 'VBP'),
#   ('acidity', 'NN'),
#   ('dry', 'JJ'),
#   ('spice', 'NN')],
#  [('coffee', 'NN'),
#   ('supported', 'VBD'),
#   ('end', 'JJ'),
#   ('cabernet', 'NN'),
#   ('soft', 'JJ'),
#   ('attractive', 'JJ'),
#   ('flavor', 'NN'),
#   ('priced', 'VBN'),
#   ('wine', 'IN'),
#   ('value', 'NN'),
#   ('finishing', 'VBG'),
#   ('strong', 'JJ'),
#   ('resulting', 'VBG'),
#   ('oaky', 'JJ'),
#   ('structure', 'NN'),
#   ('15', 'CD'),
#   ('merlot', 'NN'),
#   ('chocolate', 'NN'),
#   ('complete', 'JJ'),
#   ('picture', 'NN'),
#   ('supple', 'NN'),
#   ('plum', 'NN'),
#   ('envelopes', 'NNS'),
#   ('immediate', 'VBP'),
#   ('accessibility', 'NN')],
#  [('citrus', 'NN'),
#   ('taut', 'JJ'),
#   ('texture', 'NN'),
#   ('spicy', 'NN'),
#   ('tight', 'VBD'),
#   ('food', 'NN'),
#   ('wine', 'NN'),
#   ('almost', 'RB'),
#   ('crisp', 'JJ'),
#   ('aftertaste', 'NN'),
#   ('dry', 'JJ'),
#   ('well', 'RB'),
#   ('pepper', 'IN'),
#   ('strongly', 'RB'),
#   ('mineral', 'JJ'),
#   ('character', 'NN'),
#   ('layered', 'VBD')],
#  [('otherwise', 'RB'),
#   ('juicy', 'NN'),
#   ('explosion', 'NN'),
#   ('slightly', 'RB'),
#   ('reduced', 'VBN'),
#   ('whole', 'NN'),
#   ('accented', 'VBN'),
#   ('throughout', 'IN'),
#   ('wine', 'NN'),
#   ('offers', 'NNS'),
#   ('rich', 'JJ'),
#   ('black', 'JJ'),
#   ('cherry', 'NN'),
#   ('firm', 'NN'),
#   ('oak', 'VBZ'),
#   ('tannic', 'JJ'),
#   ('backbone', 'NN'),
#   ('cigar', 'NN'),
#   ('box', 'NN'),
#   ('chalky', 'NN')],
#  [('drying', 'VBG'),
#   ('tannins', 'NNS'),
#   ('give', 'JJ'),
#   ('include', 'VBP'),
#   ('roasted', 'VBN'),
#   ('coffee', 'JJ'),
#   ('bean', 'NN'),
#   ('espresso', 'NN'),
#   ('palate', 'NN'),
#   ('astringent', 'NN'),
#   ('carry', 'VBP'),
#   ('rather', 'RB'),
#   ('abrupt', 'JJ'),
#   ('finish', 'JJ'),
#   ('chocolate', 'NN'),
#   ('together', 'RB'),
#   ('oak', 'JJ'),
#   ('vanilla', 'NN'),
#   ('coconut', 'NN'),
#   ('dominated', 'VBD'),
#   ('plum', 'JJ'),
#   ('driven', 'JJ'),
#   ('aromas', 'NNS')],
#  [('flavors', 'NNS'),
#   ('winemaking', 'VBG'),
#   ('tradition', 'NN'),
#   ('six', 'CD'),
#   ('generations', 'NNS'),
#   ('classic', 'JJ'),
#   ('california', 'NN'),
#   ('buttercream', 'NN'),
#   ('aroma', 'NN'),
#   ('cut', 'NN'),
#   ('barely', 'RB'),
#   ('ripe', 'JJ'),
#   ('pineapple', 'NNS'),
#   ('prove', 'VBP'),
#   ('approachable', 'JJ'),
#   ('building', 'NN'),
#   ('leaner', 'NN'),
#   ('style', 'NN'),
#   ('winery', 'NN'),
#   ('trends', 'VBZ'),
#   ('toward', 'IN'),
#   ('tart', 'NN'),
#   ('green', 'JJ'),
#   ('apple', 'NN'),
#   ('150', 'CD'),
#   ('years', 'NNS'),
#   ('distinctive', 'JJ'),
#   ('good', 'JJ'),
#   ('everyday', 'NN'),
#   ('sipping', 'VBG'),
#   ('wine', 'JJ'),
#   ('range', 'NN'),
#   ('pear', 'NN')],
#  [('mineral', 'JJ'),
#   ('easy', 'JJ'),
#   ('quaffer', 'NN'),
#   ('sprightly', 'RB'),
#   ('toned', 'VBD'),
#   ('riesling', 'VBG'),
#   ('refreshing', 'VBG'),
#   ('lean', 'JJ'),
#   ('wide', 'JJ'),
#   ('appeal', 'NN'),
#   ('dry', 'JJ'),
#   ('zesty', 'NN'),
#   ('orange', 'NN'),
#   ('peels', 'NNS'),
#   ('apple', 'NN'),
#   ('notes', 'NNS'),
#   ('abound', 'VBP'),
#   ('yet', 'RB'),
#   ('racy', 'JJ'),
#   ('palate', 'NN')],
#  [('plum', 'NN'),
#   ('flavors', 'NNS'),
#   ('features', 'VBZ'),
#   ('tobacco', 'JJ'),
#   ('finish', 'NN'),
#   ('braced', 'VBD'),
#   ('berry', 'NN'),
#   ('baked', 'VBD'),
#   ('flavor', 'JJ'),
#   ('balance', 'NN'),
#   ('cheesy', 'NN'),
#   ('oak', 'NN'),
#   ('aromas', 'VBP'),
#   ('feed', 'VBN'),
#   ('peppery', 'NN'),
#   ('accents', 'NNS'),
#   ('respectable', 'JJ'),
#   ('weight', 'JJ'),
#   ('bolt', 'NN'),
#   ('molasses', 'NNS'),
#   ('acidity', 'NN'),
#   ('saucy', 'VBP'),
#   ('red', 'JJ'),
#   ('mildly', 'RB'),
#   ('green', 'JJ'),
#   ('balsamic', 'JJ'),
#   ('vinegar', 'NN'),
#   ('compact', 'NN'),
#   ('set', 'VBN'),
#   ('palate', 'NN')],
#  [('dark', 'JJ'),
#   ('smoldering', 'VBG'),
#   ('oak', 'NN'),
#   ('finishes', 'NNS'),
#   ('meaty', 'VBP'),
#   ('thickens', 'NNS'),
#   ('raw', 'JJ'),
#   ('black', 'JJ'),
#   ('cherry', 'NN'),
#   ('aromas', 'IN'),
#   ('direct', 'JJ'),
#   ('character', 'NN'),
#   ('berry', 'NN'),
#   ('fruits', 'NNS'),
#   ('good', 'JJ'),
#   ('apparent', 'JJ'),
#   ('extract', 'NN'),
#   ('becoming', 'VBG'),
#   ('flavor', 'NN'),
#   ('profile', 'NN'),
#   ('driven', 'RB'),
#   ('simple', 'JJ'),
#   ('hot', 'JJ'),
#   ('juicy', 'NN'),
#   ('feel', 'NN'),
#   ('time', 'NN')],
#  [('full', 'JJ'),
#   ('clove', 'NN'),
#   ('blackberry', 'NN'),
#   ('fruit', 'NN'),
#   ('dominate', 'VBP'),
#   ('nose', 'NNS'),
#   ('based', 'VBN'),
#   ('aromas', 'RB'),
#   ('rise', 'JJ'),
#   ('flavors', 'NNS'),
#   ('finish', 'VBP'),
#   ('leather', 'JJR'),
#   ('hickory', 'JJ'),
#   ('mint', 'NN'),
#   ('carry', 'NN'),
#   ('charred', 'VBD'),
#   ('wood', 'NN'),
#   ('tannic', 'JJ'),
#   ('forceful', 'JJ'),
#   ('oak', 'NN'),
#   ('bodied', 'VBD'),
#   ('top', 'JJ'),
#   ('heavily', 'RB'),
#   ('oaked', 'VBD'),
#   ('tinto', 'IN'),
#   ('fino', 'NN'),
#   ('desiccated', 'VBN'),
#   ('woodspice', 'NN'),
#   ('sit', 'NN')],
#  [('slightly', 'RB'),
#   ('restrained', 'VBN'),
#   ('menthol', 'NN'),
#   ('notes', 'NNS'),
#   ('riding', 'VBG'),
#   ('nose', 'JJ'),
#   ('enjoyed', 'VBN'),
#   ('back', 'RP'),
#   ('cabernet', 'NN'),
#   ('franc', 'NN'),
#   ('ready', 'JJ'),
#   ('riper', 'NN'),
#   ('red', 'JJ'),
#   ('fruit', 'NN'),
#   ('aromas', 'NN'),
#   ('pervade', 'NN'),
#   ('cigar', 'NN'),
#   ('box', 'NN'),
#   ('cherry', 'VBP'),
#   ('palate', 'NN'),
#   ('crushed', 'VBN'),
#   ('pepper', 'IN'),
#   ('plum', 'NN'),
#   ('specked', 'VBD'),
#   ('sauvignon', 'JJ'),
#   ('blend', 'JJ'),
#   ('entry', 'NN'),
#   ('opens', 'VBZ'),
#   ('approachable', 'JJ'),
#   ('merlot', 'NN')],
#  [('offering', 'VBG'),
#   ('nature', 'JJ'),
#   ('levity', 'NN'),
#   ('notes', 'NNS'),
#   ('palate', 'VBP'),
#   ('ample', 'JJ'),
#   ('toasted', 'JJ'),
#   ('vanilla', 'NN'),
#   ('tart', 'NN'),
#   ('red', 'JJ'),
#   ('currant', 'JJ'),
#   ('shine', 'NN'),
#   ('dusty', 'NN'),
#   ('tobacco', 'NN'),
#   ('oak', 'NN'),
#   ('driven', 'JJ'),
#   ('black', 'JJ'),
#   ('pepper', 'NN'),
#   ('bit', 'NN'),
#   ('ripe', 'JJ'),
#   ('aromas', 'RB'),
#   ('dark', 'JJ'),
#   ('berries', 'NNS'),
#   ('mingle', 'VBP')],
#  [('tart', 'NN'),
#   ('berry', 'NN'),
#   ('chocolate', 'NN'),
#   ('whether', 'IN'),
#   ('oak', 'NN'),
#   ('staved', 'VBD'),
#   ('fair', 'JJ'),
#   ('value', 'NN'),
#   ('aged', 'VBN'),
#   ('hint', 'JJ'),
#   ('stem', 'NN'),
#   ('along', 'IN'),
#   ('neutral', 'JJ'),
#   ('drink', 'NN'),
#   ('widely', 'RB'),
#   ('available', 'JJ'),
#   ('oregon', 'NN'),
#   ('pinot', 'NN'),
#   ('herb', 'NN'),
#   ('indicated', 'VBD'),
#   ('wine', 'JJ'),
#   ('six', 'CD'),
#   ('months', 'NNS'),
#   ('sleek', 'JJ'),
#   ('mix', 'NN')],
#  [('palate', 'NN'),
#   ('offers', 'NNS'),
#   ('passion', 'NN'),
#   ('fruit', 'NN'),
#   ('citrus', 'JJ'),
#   ('mineral', 'JJ'),
#   ('alongside', 'NN'),
#   ('bright', 'JJ'),
#   ('acidity', 'NN'),
#   ('hint', 'NN'),
#   ('delicate', 'NN'),
#   ('aromas', 'IN'),
#   ('recall', 'JJ'),
#   ('white', 'JJ'),
#   ('flower', 'NN'),
#   ('lime', 'NN'),
#   ('peach', 'NN')],
#  [('bit', 'NN'),
#   ('flat', 'JJ'),
#   ('flavors', 'NNS'),
#   ('tempt', 'VBP'),
#   ('sour', 'JJ'),
#   ('cherries', 'NNS'),
#   ('emerges', 'VBZ'),
#   ('tension', 'NN'),
#   ('bolstered', 'VBD'),
#   ('wine', 'JJ'),
#   ('black', 'JJ'),
#   ('licorice', 'NN'),
#   ('nose', 'JJ'),
#   ('geneseo', 'NN'),
#   ('district', 'NN'),
#   ('offers', 'NNS'),
#   ('aromas', 'VBP'),
#   ('acidity', 'NN'),
#   ('first', 'RB'),
#   ('enough', 'RB'),
#   ('cigar', 'NN'),
#   ('box', 'NN'),
#   ('plums', 'NNS'),
#   ('midpalate', 'VBP')],
#  [('flavors', 'NNS'),
#   ('drying', 'VBG'),
#   ('tannins', 'NNS'),
#   ('provide', 'VBP'),
#   ('black', 'JJ'),
#   ('cherry', 'NN'),
#   ('oak', 'NN'),
#   ('carry', 'VBP'),
#   ('along', 'IN'),
#   ('firm', 'JJ'),
#   ('toast', 'NN'),
#   ('roasted', 'VBD'),
#   ('coffee', 'NN'),
#   ('beans', 'NNS'),
#   ('extracted', 'VBD'),
#   ('palate', 'NN'),
#   ('blackcurrant', 'NN'),
#   ('framework', 'NN'),
#   ('aromas', 'NN'),
#   ('prune', 'NN')],
#  [('designated', 'VBN'),
#   ('pinot', 'JJ'),
#   ('production', 'NN'),
#   ('smoky', 'NN'),
#   ('spice', 'NN'),
#   ('smooth', 'JJ'),
#   ('texture', 'NN'),
#   ('blackberry', 'NN'),
#   ('steeped', 'VBD'),
#   ('earth', 'JJ'),
#   ('intermingle', 'NN'),
#   ('around', 'RB'),
#   ('robust', 'JJ'),
#   ('aromas', 'RB'),
#   ('small', 'JJ'),
#   ('wet', 'JJ'),
#   ('forest', 'JJS'),
#   ('floor', 'NN'),
#   ('hails', 'VBZ'),
#   ('offers', 'NNS'),
#   ('intense', 'JJ'),
#   ('full', 'JJ'),
#   ('oak', 'NN'),
#   ('bodied', 'VBD'),
#   ('raspberry', 'JJ'),
#   ('vineyard', 'RB'),
#   ('high', 'JJ'),
#   ('elevation', 'NN'),
#   ('site', 'NN')],
#  [('yellow', 'JJ'),
#   ('flower', 'NN'),
#   ('delicate', 'NN'),
#   ('notes', 'NNS'),
#   ('apricot', 'VBP'),
#   ('pretty', 'RB'),
#   ('aromas', 'RB'),
#   ('nose', 'JJ'),
#   ('vanilla', 'NN'),
#   ('lightly', 'RB'),
#   ('toasted', 'VBD'),
#   ('oak', 'JJ'),
#   ('alongside', 'RB'),
#   ('crisp', 'JJ'),
#   ('acidity', 'NN'),
#   ('stone', 'NN'),
#   ('fruit', 'NN'),
#   ('lead', 'NN'),
#   ('bright', 'JJ'),
#   ('palate', 'NN'),
#   ('offers', 'NNS'),
#   ('apple', 'NN')],
#  [('soft', 'JJ'),
#   ('espresso', 'NNS'),
#   ('alongside', 'RB'),
#   ('round', 'VBP'),
#   ('tannins', 'NNS'),
#   ('informal', 'JJ'),
#   ('palate', 'NN'),
#   ('offers', 'NNS'),
#   ('sour', 'VBP'),
#   ('cherry', 'NN'),
#   ('aromas', 'VBP'),
#   ('recall', 'NN'),
#   ('ripe', 'NN'),
#   ('dark', 'NN'),
#   ('berry', 'NN'),
#   ('drink', 'VBP'),
#   ('soon', 'RB'),
#   ('toast', 'JJ'),
#   ('vanilla', 'NN'),
#   ('whiff', 'NN'),
#   ('hint', 'NN'),
#   ('cake', 'NN'),
#   ('spice', 'NN')],
#  [('vanilla', 'NN'),
#   ('alongside', 'RB'),
#   ('dusty', 'JJ'),
#   ('tannins', 'NNS'),
#   ('palate', 'VBP'),
#   ('offers', 'NNS'),
#   ('ripe', 'JJ'),
#   ('black', 'JJ'),
#   ('berry', 'NN'),
#   ('aromas', 'RB'),
#   ('suggest', 'JJ'),
#   ('mature', 'NN'),
#   ('espresso', 'NN'),
#   ('cocoa', 'NN'),
#   ('anise', 'NN'),
#   ('toast', 'NN'),
#   ('oak', 'NN'),
#   ('scorched', 'VBD'),
#   ('earth', 'NN'),
#   ('animal', 'NN')],
#  [('california', 'NN'),
#   ('clarksburg', 'NN'),
#   ('trace', 'NN'),
#   ('becoming', 'VBG'),
#   ('several', 'JJ'),
#   ('vineyards', 'NNS'),
#   ('area', 'NN'),
#   ('chenin', 'NN'),
#   ('blanc', 'NN'),
#   ('bottling', 'VBG'),
#   ('notes', 'NNS'),
#   ('balanced', 'VBD'),
#   ('drink', 'NN'),
#   ('sweetness', 'NN'),
#   ('residual', 'JJ'),
#   ('sugar', 'NN'),
#   (')', ')'),
#   ('.', '.')],
#  [('bright', 'JJ'),
#   ('wine', 'NN'),
#   ('light', 'NN'),
#   ('tannins', 'NNS'),
#   ('giving', 'VBG'),
#   ('red', 'JJ'),
#   ('cherry', 'NN'),
#   ('fruit', 'NN'),
#   ('comes', 'VBZ'),
#   ('laced', 'JJ'),
#   ('open', 'JJ'),
#   ('juicy', 'NN'),
#   ('character', 'NN')],
#  [('nero', 'JJ'),
#   ('clean', 'JJ'),
#   ('bright', 'JJ'),
#   ('quality', 'NN'),
#   ('sharp', 'JJ'),
#   ('easy', 'JJ'),
#   ('red', 'JJ'),
#   ('wine', 'NN'),
#   ('meat', 'NN'),
#   ('sauce', 'NN'),
#   ('merlot', 'NN'),
#   ('avola', 'IN'),
#   ('form', 'NN'),
#   ('base', 'NN'),
#   ('pork', 'NN'),
#   ('roast', 'NN'),
#   ('fruit', 'NN'),
#   ('would', 'MD'),
#   ('pair', 'VB'),
#   ('fettuccine', 'VB')],
#  [('extended', 'VBN'),
#   ('calanìca', 'NN'),
#   ('series', 'NN'),
#   ('honeysuckle', 'NN'),
#   ('mouth', 'NNP'),
#   ('fruit', 'NN'),
#   ('flavors', 'NNS'),
#   ('backed', 'VBD'),
#   ('touches', 'NNS'),
#   ('cut', 'VBD'),
#   ('grass', 'NN'),
#   ('viognier', 'NN'),
#   ('blend', 'NN'),
#   ('shows', 'VBZ'),
#   ('aromas', 'RP'),
#   ('ripe', 'JJ'),
#   ('yellow', 'JJ'),
#   ('part', 'NN'),
#   ('jasmine', 'NN'),
#   ('wild', 'JJ'),
#   ('sage', 'NN'),
#   ('grillo', 'NN')],
#  [('flavors', 'NNS'),
#   ('currants', 'NNS'),
#   ('cabernet', 'NN'),
#   ('franc', 'NN'),
#   ('made', 'VBD'),
#   ('licorice', 'NN'),
#   ('dry', 'JJ'),
#   ('sauvignon', 'NN'),
#   ('spices', 'NNS'),
#   ('berries', 'NNS'),
#   ('rustic', 'VBP')],
#  [('unoaked', 'JJ'),
#   ('tart', 'NN'),
#   ('honey', 'NN'),
#   ('green', 'JJ'),
#   ('gooseberry', 'NN'),
#   ('flavor', 'NN'),
#   ('shows', 'VBZ'),
#   ('notes', 'NNS'),
#   ('include', 'VBP'),
#   ('tropical', 'JJ'),
#   ('fruit', 'NN'),
#   ('commendable', 'JJ'),
#   ('dryness', 'NN'),
#   ('orange', 'VBP'),
#   ('new', 'JJ'),
#   ('zealand', 'NNP'),
#   ('sauvignon', 'NN'),
#   ('blanc', 'NN'),
#   ('acidity', 'NN'),
#   ('muscat', 'NN'),
#   ('splash', 'NN'),
#   ('similar', 'JJ')],
#  [('finish', 'JJ'),
#   ('touch', 'NN'),
#   ('notes', 'NNS'),
#   ('leaf', 'VBD'),
#   ('many', 'JJ'),
#   ('ripeness', 'NN'),
#   ('strongly', 'RB'),
#   ('herbal', 'JJ'),
#   ('erath', 'NN'),
#   ('2010', 'CD'),
#   ('vineyard', 'NN'),
#   ('designates', 'VBZ'),
#   ('bitterness', 'JJ'),
#   ('fruit', 'NN'),
#   ('herb', 'NN'),
#   ('create', 'VBP'),
#   ('somewhat', 'RB'),
#   ('unripe', 'JJ'),
#   ('flavor', 'NN'),
#   ('impressions', 'NNS'),
#   ('sweet', 'VBP'),
#   ('tomatoes', 'NNS'),
#   ('passes', 'NNS')],
#  [('mixed', 'JJ'),
#   ('white', 'JJ'),
#   ('flower', 'NN'),
#   ('apple', 'NN'),
#   ('aromas', 'NN'),
#   ('carry', 'VBP'),
#   ('viognier', 'JJ'),
#   ('component', 'NN'),
#   ('chardonnay', 'NN'),
#   ('fills', 'VBZ'),
#   ('sweet', 'JJ'),
#   ('flavors', 'NNS'),
#   ('lychee', 'VBP'),
#   ('peach', 'NN'),
#   ('plump', 'NN'),
#   ('typical', 'JJ'),
#   ('oily', 'RB'),
#   ('greener', 'NN'),
#   ('notes', 'NNS'),
#   ('80', 'CD'),
#   ('warm', 'JJ'),
#   ('climate', 'NN'),
#   ('melon', 'NN'),
#   ('short', 'JJ'),
#   ('finish', 'NN'),
#   ('lime', 'JJ'),
#   ('blend', 'NN'),
#   ('chunky', 'NN'),
#   ('feeling', 'VBG'),
#   ('palate', 'JJ'),
#   ('bears', 'NNS'),
#   ('powdery', 'RB'),
#   ('grass', 'VBP'),
#   ('mellow', 'JJ'),
#   ('bouquet', 'NN')],
#  [('concentrated', 'VBN'),
#   ('cabernet', 'NN'),
#   ('offers', 'NNS'),
#   ('aromas', 'VBP'),
#   ('cured', 'VBN'),
#   ('meat', 'NN'),
#   ('barbecue', 'NN'),
#   ('spice', 'NN'),
#   ('chewy', 'NN'),
#   ('feel', 'VB'),
#   ('teriyaki', 'JJ'),
#   ('sauce', 'NN'),
#   ('flavors', 'NNS'),
#   ('give', 'VBP'),
#   ('wine', 'NN'),
#   ('bold', 'JJ'),
#   ('rosemary', 'JJ'),
#   ('dried', 'VBD'),
#   ('fruit', 'NN')],
#  [('inky', 'NN'),
#   ('soft', 'JJ'),
#   ('wine', 'NN'),
#   ('rum', 'NN'),
#   ('cake', 'VBP'),
#   ('color', 'NN'),
#   ('plump', 'NN'),
#   ('aromas', 'NN'),
#   ('ripe', 'NN'),
#   ('fruit', 'NN'),
#   ('blackberry', 'NN'),
#   ('jam', 'NN'),
#   ('smooth', 'JJ'),
#   ('palate', 'NN')],
#  [('fruit', 'NN'),
#   ('recycled', 'VBD'),
#   ('paper', 'NN'),
#   ('organic', 'JJ'),
#   ('grapes', 'NNS'),
#   ('finish', 'JJ'),
#   ('quality', 'NN'),
#   ('wine', 'NN'),
#   ('bright', 'NN'),
#   ('berry', 'NN'),
#   ('flavor', 'NN'),
#   ('made', 'VBN'),
#   ('nice', 'JJ'),
#   ('part', 'NN'),
#   ('printed', 'VBD'),
#   ('label', 'NN'),
#   ('juicy', 'NN'),
#   ('palate', 'VBP'),
#   ('natural', 'JJ'),
#   ('movement', 'NN'),
#   ('vegetable', 'JJ'),
#   ('ink', 'NN')],
#  [('mineral', 'JJ'),
#   ('note', 'NN'),
#   ('citrus', 'NN'),
#   ('backed', 'VBD'),
#   ('almond', 'NN'),
#   ('blossom', 'NN'),
#   ('touches', 'VBZ'),
#   ('one', 'CD'),
#   ('sicily', 'NN'),
#   ('catarratto', 'VBZ'),
#   ('widely', 'RB'),
#   ('farmed', 'VBN'),
#   ('white', 'JJ'),
#   ('grape', 'NN'),
#   ('varieties', 'NNS'),
#   ('expression', 'NN'),
#   ('shows', 'NNS')],
#  [('touch', 'JJ'),
#   ('notes', 'NNS'),
#   ('earthy', 'JJ'),
#   ('herbs', 'JJ'),
#   ('brings', 'NNS'),
#   ('brambly', 'RB'),
#   ('berry', 'VBP'),
#   ('flavors', 'NNS'),
#   ('play', 'VBP'),
#   ('tannic', 'JJ'),
#   ('wine', 'NN'),
#   ('along', 'IN'),
#   ('bitterness', 'NN'),
#   ('tannins', 'NNS'),
#   ('stiff', 'JJ'),
#   ('slowly', 'RB'),
#   ('opens', 'NNS')],
#  [('soft', 'JJ'),
#   ('red', 'JJ'),
#   ('berry', 'NN'),
#   ('flavor', 'NN'),
#   ('ripe', 'NN'),
#   ('fruit', 'NN'),
#   ('acidity', 'NN'),
#   ('festive', 'JJ'),
#   ('wine', 'NN'),
#   ('plus', 'CC')],
#  [('citrus', 'NN'),
#   ('clean', 'NN'),
#   ('rich', 'JJ'),
#   ('streak', 'NN'),
#   ('pear', 'JJ'),
#   ('tropical', 'JJ'),
#   ('fruit', 'NN'),
#   ('flavors', 'NNS'),
#   ('slightly', 'RB'),
#   ('oaked', 'VBD'),
#   ('sauvignon', 'JJ'),
#   ('blanc', 'NN'),
#   ('instant', 'JJ'),
#   ('likeability', 'NN'),
#   ('honey', 'NN'),
#   ('sweetens', 'VBZ'),
#   ('grapefruit', 'NN'),
#   ('sections', 'NNS'),
#   ('green', 'JJ'),
#   ('salad', 'JJ'),
#   ('pair', 'NN'),
#   ('dry', 'JJ'),
#   ('ham', 'NN'),
#   ('brisk', 'JJ'),
#   ('mouthfeel', 'NN'),
#   ('gives', 'VBZ'),
#   ('asian', 'JJ'),
#   ('fare', 'NN')],
#  [('modest', 'JJ'),
#   ('finish', 'JJ'),
#   ('delivers', 'NNS'),
#   ('raspberry', 'VBP'),
#   ('plum', 'JJ'),
#   ('flavors', 'NNS'),
#   ('racy', 'VBP'),
#   ('tangy', 'JJ'),
#   ('herb', 'NN'),
#   ('notes', 'NNS'),
#   ('cola', 'VBP'),
#   ('berry', 'NN'),
#   ('aroma', 'NN'),
#   ('comes', 'VBZ'),
#   ('palate', 'VB')],
#  [('35', 'CD'),
#   ('drying', 'VBG'),
#   ('tannins', 'NNS'),
#   ('50', 'CD'),
#   ('caramel', 'NN'),
#   ('15', 'CD'),
#   ('oaky', 'JJ'),
#   ('wine', 'NN'),
#   ('oak', 'NN'),
#   ('finessed', 'VBD'),
#   ('dripping', 'VBG'),
#   ('vanilla', 'NN'),
#   ('notes', 'NNS'),
#   ('texture', 'VBP'),
#   ('midpalate', 'NN'),
#   ('tannat', 'NN'),
#   ('latch', 'NN'),
#   ('onto', 'IN'),
#   ('pinotage', 'NN'),
#   ('petit', 'NN'),
#   ('verdot', 'NN'),
#   ('graceful', 'JJ'),
#   ('right', 'RB'),
#   ('driven', 'RB'),
#   ('finish', 'JJ'),
#   ('starting', 'VBG'),
#   ('blocks', 'NNS'),
#   ('eccentric', 'JJ'),
#   ('blend', 'NN')],
#  [('spaghetti', 'NNS'),
#   ('con', 'VBP'),
#   ('vongole', 'JJ'),
#   ('fresh', 'JJ'),
#   ('offers', 'NNS'),
#   ('pretty', 'RB'),
#   ('citrus', 'VBP'),
#   ('tones', 'NNS'),
#   ('followed', 'VBD'),
#   ('clean', 'JJ'),
#   ('spicy', 'NN'),
#   ('drying', 'VBG'),
#   ('mineral', 'JJ'),
#   ('nuance', 'NN'),
#   ('fried', 'VBD'),
#   ('seafood', 'NN'),
#   ('would', 'MD'),
#   ('pair', 'VB')],
#  [('flavors', 'NNS'),
#   ('honey', 'VBP'),
#   ('white', 'JJ'),
#   ('sugar', 'NN'),
#   ('brightened', 'VBD'),
#   ('orange', 'JJ'),
#   ('sweet', 'JJ'),
#   ('wine', 'NN'),
#   ('vanilla', 'NN'),
#   ('crisp', 'NN'),
#   ('acidity', 'NN')],
#  [('intense', 'JJ'),
#   ('graham', 'NN'),
#   ('cracker', 'NN'),
#   ('adds', 'VBZ'),
#   ('interest', 'NN'),
#   ('apricot', 'NN'),
#   ('kiwi', 'NN'),
#   ('sprinkling', 'VBG'),
#   ('wine', 'JJ'),
#   ('hits', 'NNS'),
#   ('bottling', 'VBG'),
#   ('resembles', 'NNS'),
#   ('glazed', 'VBN'),
#   ('roasted', 'VBD'),
#   ('chicken', 'JJ'),
#   ('pair', 'NN'),
#   ('palate', 'VBP'),
#   ('like', 'IN'),
#   ('new', 'JJ'),
#   ('zealand', 'NNP'),
#   ('paradigm', 'NN'),
#   ('provides', 'VBZ'),
#   ('plenty', 'JJ'),
#   ('grassy', 'NN'),
#   ('gooseberry', 'NN'),
#   ('flavor', 'NN'),
#   ('passion', 'NN'),
#   ('fruit', 'NN'),
#   ('bearing', 'NN'),
#   ('aromas', 'NN'),
#   ('sauvignon', 'NN'),
#   ('blanc', 'NN'),
#   ('punch', 'NN'),
#   ('fleshy', 'JJ'),
#   ('fist', 'NN'),
#   ('grapefruit', 'NN')],
#  [('fruity', 'NN'),
#   ('juicy', 'NN'),
#   ('red', 'JJ'),
#   ('soft', 'JJ'),
#   ('cherry', 'NN'),
#   ('fruits', 'NNS'),
#   ('full', 'JJ'),
#   ('giving', 'VBG'),
#   ('ripe', 'JJ'),
#   ('wine', 'NN'),
#   ('open', 'JJ'),
#   ('sweet', 'JJ'),
#   ('character', 'NN'),
#   ('ready', 'JJ'),
#   ('generous', 'JJ'),
#   ('gentle', 'NN'),
#   ('tannins', 'NNS'),
#   ('richness', 'VBP'),
#   ('drink', 'VB')],
#  [('cured', 'VBN'),
#   ('meat', 'NN'),
#   ('cassis', 'NN'),
#   ('finish', 'JJ'),
#   ('avola', 'NN'),
#   ('touch', 'JJ'),
#   ('almond', 'NN'),
#   ('bitterness', 'NN'),
#   ('syrah', 'NN'),
#   ('opens', 'VBZ'),
#   ('tobacco', 'JJ'),
#   ('savory', 'NN'),
#   ('aromas', 'NN'),
#   ('nero', 'JJ'),
#   ('blend', 'NN'),
#   ('wet', 'NN'),
#   ('earth', 'NN'),
#   ('dried', 'VBD'),
#   ('berry', 'NN')],
#  [('grittiness', 'NN'),
#   ('tarry', 'NN'),
#   ('leafy', 'JJ'),
#   ('flight', 'NN'),
#   ('hard', 'RB'),
#   ('tasted', 'VBD'),
#   ('finish', 'JJ'),
#   ('herbal', 'JJ'),
#   ('aroma', 'NN'),
#   ('length', 'NN'),
#   ('short', 'JJ'),
#   ('spicy', 'NN'),
#   ('08', 'CD'),
#   ('casa', 'NN'),
#   ('silva', 'NN'),
#   ('2009', 'CD'),
#   ('petit', 'NN'),
#   ('verdot', 'NN'),
#   ('fruit', 'NN'),
#   ('long', 'RB'),
#   ('much', 'JJ'),
#   ('different', 'JJ'),
#   ('palate', 'NN'),
#   ('feels', 'NNS'),
#   ('snappy', 'JJ'),
#   ('miss', 'JJ'),
#   ('saltiness', 'NN'),
#   ('plus', 'CC'),
#   ('raw', 'JJ'),
#   ('feel', 'NN')],
#  [('added', 'VBD'),
#   ('touch', 'JJ'),
#   ('finish', 'JJ'),
#   ('bright', 'JJ'),
#   ('acidity', 'NN'),
#   ('cherry', 'NN'),
#   ('cola', 'NN'),
#   ('expression', 'NN'),
#   ('monica', 'NN'),
#   ('grape', 'NN'),
#   ('often', 'RB'),
#   ('shows', 'VBZ'),
#   ('black', 'JJ'),
#   ('pepper', 'IN'),
#   ('sour', 'JJ'),
#   ('fruit', 'NN'),
#   ('aromas', 'NN'),
#   ('raw', 'JJ'),
#   ('quality', 'NN'),
#   ('rustic', 'NN')],
#  [('fruity', 'NN'),
#   ('bright', 'VBD'),
#   ('lightly', 'RB'),
#   ('herbaceous', 'JJ'),
#   ('pink', 'VBP'),
#   ('grapefruit', 'NN'),
#   ('flavor', 'NN'),
#   ('wine', 'VBP'),
#   ('ready', 'JJ'),
#   ('drink', 'VBP'),
#   ('months', 'NNS'),
#   ('easy', 'JJ'),
#   ('fine', 'JJ'),
#   ('textured', 'VBN'),
#   ('acidity', 'NN'),
#   ('along', 'IN')],
#  [('avola', 'NN'),
#   ('cola', 'NN'),
#   ('bright', 'VBD'),
#   ('dusty', 'JJ'),
#   ('mineral', 'NN'),
#   ('accents', 'NNS'),
#   ('blue', 'JJ'),
#   ('flower', 'JJR'),
#   ('nerello', 'JJ'),
#   ('mascalese', 'JJ'),
#   ('lean', 'JJ'),
#   ('nero', 'NN'),
#   ('blend', 'NN'),
#   ('delivers', 'NNS'),
#   ('forest', 'VBP'),
#   ('berry', 'NN'),
#   ('easy', 'JJ'),
#   ('palate', 'NN')],
#  [('soft', 'JJ'),
#   ('shows', 'NNS'),
#   ('jelly', 'RB'),
#   ('like', 'IN'),
#   ('flavors', 'NNS'),
#   ('bounty', 'VBP'),
#   ('earthy', 'JJ'),
#   ('tones', 'NNS'),
#   ('mouthfeel', 'NN'),
#   ('buttered', 'VBD'),
#   ('toast', 'JJ'),
#   ('oak', 'JJ'),
#   ('form', 'NN'),
#   ('orange', 'NN'),
#   ('pear', 'JJ'),
#   ('caramel', 'NN'),
#   ('notes', 'NNS')],
#  [('body', 'NN'),
#   ('plenty', 'JJ'),
#   ('pear', 'JJ'),
#   ('flavors', 'NNS'),
#   ('full', 'JJ'),
#   ('plus', 'CC'),
#   ('slight', 'JJ'),
#   ('brown', 'NN'),
#   ('sugar', 'NN'),
#   ('weighty', 'VBP'),
#   ('vanilla', 'NN'),
#   ('notes', 'NNS'),
#   ('medium', 'VBP'),
#   ('lime', 'NN'),
#   ('creamy', 'NN')],
#  [('stone', 'NN'),
#   ('fruit', 'NN'),
#   ('toasted', 'VBD'),
#   ('almond', 'NN'),
#   ('citrus', 'NNS'),
#   ('start', 'VBP'),
#   ('touch', 'JJ'),
#   ('deliver', 'NN'),
#   ('notes', 'NNS'),
#   ('glass', 'VBP'),
#   ('crisp', 'NN'),
#   ('grillo', 'NN'),
#   ('revs', 'NN'),
#   ('lemon', 'JJ'),
#   ('tart', 'NN'),
#   ('mouthfeel', 'NN'),
#   ('simple', 'NN'),
#   ('crushed', 'VBD')],
#  [('fresh', 'JJ'),
#   ('finish', 'NN'),
#   ('lightly', 'RB'),
#   ('herbal', 'JJ'),
#   ('strawberry', 'NN'),
#   ('dry', 'JJ'),
#   ('spice', 'NN'),
#   ('red', 'VBD'),
#   ('fruit', 'NN'),
#   ('raspberry', 'NN'),
#   ('aromas', 'RB'),
#   ('light', 'JJ'),
#   ('oaky', 'NNS'),
#   ('snappy', 'JJ'),
#   ('lean', 'JJ'),
#   ('flavors', 'NNS'),
#   ('juicy', 'VBP'),
#   ('authentic', 'JJ'),
#   ('palate', 'NN')],
#  [('bit', 'NN'),
#   ('flat', 'JJ'),
#   ('grainy', 'NN'),
#   ('tannins', 'NNS'),
#   ('herb', 'VBP'),
#   ('discern', 'JJ'),
#   ('cranberry', 'NN'),
#   ('falls', 'VBZ'),
#   ('followed', 'VBN'),
#   ('tart', 'JJ'),
#   ('flavors', 'NNS'),
#   ('variety', 'NN'),
#   ('seems', 'VBZ'),
#   ('hard', 'JJ'),
#   ('aromas', 'NN'),
#   ('barrel', 'NN'),
#   ('spice', 'NN')],
#  [('dense', 'NN'),
#   ('accents', 'NNS'),
#   ('plenty', 'VBP'),
#   ('leather', 'CC'),
#   ('full', 'JJ'),
#   ('ripe', 'NN'),
#   ('graphite', 'JJ'),
#   ('wine', 'NN'),
#   ('jammy', 'NN'),
#   ('oak', 'NN'),
#   ('vanilla', 'NN'),
#   ('indeterminate', 'NN'),
#   ('structure', 'NN'),
#   ('syrupy', 'NN'),
#   ('plum', 'NN'),
#   ('bodied', 'VBD')],
#  [('simple', 'JJ'),
#   ('palate', 'NN'),
#   ('along', 'IN'),
#   ('easygoing', 'VBG'),
#   ('nature', 'NN'),
#   ('touch', 'JJ'),
#   ('black', 'JJ'),
#   ('plum', 'NN'),
#   ('pliant', 'NN'),
#   ('tannins', 'NNS'),
#   ('give', 'VBP'),
#   ('cedar', 'NN'),
#   ('carry', 'NN'),
#   ('drink', 'VBP'),
#   ('soon', 'RB'),
#   ('vanilla', 'NN'),
#   ('densely', 'RB'),
#   ('hued', 'VBN'),
#   ('wine', 'NN'),
#   ('aromas', 'NN')],
#  [('flavors', 'NNS'),
#   ('notes', 'NNS'),
#   ('elegant', 'JJ'),
#   ('tart', 'NN'),
#   ('lightly', 'RB'),
#   ('gritty', 'JJ'),
#   ('tannins', 'NNS'),
#   ('backing', 'VBG'),
#   ('best', 'RB'),
#   ('suited', 'VBN'),
#   ('brooding', 'NN'),
#   ('dinner', 'NN'),
#   ('table', 'JJ'),
#   ('cherry', 'NN'),
#   ('style', 'NN'),
#   ('aromas', 'IN'),
#   ('barrel', 'NN'),
#   ('spice', 'NN')],
#  [('soft', 'JJ'),
#   ('pinot', 'NN'),
#   ('noir', 'RB'),
#   ('ready', 'JJ'),
#   ('drink', 'VB'),
#   ('yeasty', 'JJ'),
#   ('champagne', 'NN'),
#   ('ripe', 'NN'),
#   ('red', 'JJ'),
#   ('berry', 'NN'),
#   ('fruit', 'NN'),
#   ('creamy', 'JJ'),
#   ('aftertaste', 'NN'),
#   ('fat', 'NN'),
#   ('comprised', 'VBD'),
#   ('predominantly', 'RB'),
#   ('light', 'JJ'),
#   ('acidity', 'NN')],
#  [('bottling', 'VBG'),
#   ('sip', 'JJ'),
#   ('jasmine', 'NN'),
#   ('nose', 'JJ'),
#   ('intriguing', 'JJ'),
#   ('touches', 'NNS'),
#   ('quinine', 'VBP'),
#   ('golden', 'JJ'),
#   ('apple', 'NN'),
#   ('quite', 'RB'),
#   ('delicate', 'JJ'),
#   ('sea', 'NN'),
#   ('salt', 'NN'),
#   ('wet', 'JJ'),
#   ('hay', 'NN'),
#   ('structure', 'NN'),
#   ('honey', 'NN'),
#   ('flavors', 'NNS'),
#   ('rainy', 'VBP'),
#   ('sidewalk', 'NN')],
#  [('usual', 'JJ'),
#   ('soft', 'JJ'),
#   ('warm', 'NN'),
#   ('2015', 'CD'),
#   ('vintage', 'NN'),
#   ('giving', 'VBG'),
#   ('fruity', 'NN'),
#   ('wine', 'NN'),
#   ('open', 'JJ'),
#   ('acidity', 'NN'),
#   ('lighter', 'RBR'),
#   ('drink', 'VBP'),
#   ('broad', 'JJ'),
#   ('white', 'JJ'),
#   ('fruit', 'NN'),
#   ('flavors', 'NNS'),
#   ('chablis', 'VBP'),
#   ('particularly', 'RB'),
#   ('ripe', 'JJ'),
#   ('character', 'NN')],
#  [('generous', 'JJ'),
#   ('pear', 'JJ'),
#   ('soft', 'JJ'),
#   ('melon', 'NN'),
#   ('flavors', 'NNS'),
#   ('ripe', 'VBP'),
#   ('ready', 'JJ'),
#   ('drink', 'NN'),
#   ('young', 'JJ'),
#   ('attractively', 'RB'),
#   ('character', 'JJ'),
#   ('easy', 'JJ'),
#   ('smooth', 'NN'),
#   ('rounded', 'VBD'),
#   ('wine', 'NN')],
#  [('plump', 'NN'),
#   ('cherry', 'NN'),
#   ('flavors', 'NNS'),
#   ('wood', 'VBD'),
#   ('spice', 'NN'),
#   ('rounded', 'VBD'),
#   ('cabernet', 'NN'),
#   ('franc', 'NN'),
#   ('wine', 'NN'),
#   ('brings', 'VBZ'),
#   ('disjointed', 'VBN'),
#   ('lightly', 'RB'),
#   ('volatile', 'JJ'),
#   ('aromas', 'NNS'),
#   ('woody', 'NN'),
#   ('barrel', 'NN'),
#   ('notes', 'NNS'),
#   ('merlot', 'VBP'),
#   ('vanilla', 'NN'),
#   ('blend', 'NN')],
#  [('dark', 'JJ'),
#   ('bold', 'JJ'),
#   ('character', 'NN'),
#   ('smoke', 'VBD'),
#   ('give', 'JJ'),
#   ('deny', 'NN'),
#   ('spicy', 'NN'),
#   ('full', 'JJ'),
#   ('deep', 'JJ'),
#   ('smoky', 'NN'),
#   ('bodied', 'VBD'),
#   ('wine', 'JJ'),
#   ('flavor', 'NN'),
#   ('blueberry', 'NN'),
#   ('packed', 'VBD'),
#   ('color', 'JJ'),
#   ('flavors', 'NNS'),
#   ('like', 'IN'),
#   ('cardamom', 'NN'),
#   ('aromas', 'NN'),
#   ('grilled', 'VBD'),
#   ('beef', 'NN'),
#   ('hard', 'JJ'),
#   ('fruit', 'NN'),
#   ('blackberry', 'NN')],
#  [('produce', 'NN'),
#   ('benefited', 'VBD'),
#   ('village', 'NN'),
#   ('ready', 'JJ'),
#   ('drink', 'VB'),
#   ('cooperative', 'JJ'),
#   ('ripe', 'NN'),
#   ('red', 'VBD'),
#   ('fruited', 'JJ'),
#   ('wine', 'NN'),
#   ('fine', 'NN'),
#   ('pinot', 'NN'),
#   ('noir', 'RB'),
#   ('balanced', 'VBD'),
#   ('acidity', 'NN'),
#   ('soft', 'JJ'),
#   ('aftertaste', 'NN'),
#   ('based', 'VBN'),
#   ('aÿ', 'NN')],
#  [('canned', 'VBN'),
#   ('oak', 'NN'),
#   ('seems', 'VBZ'),
#   ('overweighted', 'VBN'),
#   ('toast', 'JJ'),
#   ('lead', 'JJ'),
#   ('corn', 'NN'),
#   ('flavors', 'NNS'),
#   ('provides', 'VBZ'),
#   ('appeal', 'JJ'),
#   ('light', 'JJ'),
#   ('creamy', 'NN'),
#   ('stone', 'NN'),
#   ('fruit', 'NN'),
#   ('vanilla', 'NN'),
#   ('char', 'NN'),
#   ('aromas', 'NN')],
#  [('gravelly', 'RB'),
#   ('rustically', 'RB'),
#   ('pleasant', 'JJ'),
#   ('wine', 'NN'),
#   ('robustly', 'RB'),
#   ('dense', 'RB'),
#   ('extracted', 'VBN'),
#   ('red', 'JJ'),
#   ('full', 'JJ'),
#   ('swimming', 'NN'),
#   ('crowds', 'NN'),
#   ('texture', 'NN'),
#   ('vanilla', 'NN'),
#   ('cherry', 'VBP'),
#   ('flavor', 'NN'),
#   ('big', 'JJ'),
#   ('oak', 'NN'),
#   ('defines', 'NNS'),
#   ('pizza', 'VBP'),
#   ('nights', 'NNS'),
#   ('bodied', 'VBD')],
#  [('black', 'JJ'),
#   ('game', 'NN'),
#   ('drying', 'VBG'),
#   ('finish', 'JJ'),
#   ('somewhat', 'RB'),
#   ('disjointed', 'JJ'),
#   ('palate', 'NN'),
#   ('along', 'IN'),
#   ('underbrush', 'JJ'),
#   ('leather', 'NN'),
#   ('grainy', 'NN'),
#   ('tannins', 'NNS'),
#   ('leave', 'VBP'),
#   ('carry', 'JJ'),
#   ('suggestions', 'NNS'),
#   ('skinned', 'VBD'),
#   ('fruit', 'JJ'),
#   ('lean', 'JJ'),
#   ('licorice', 'NN'),
#   ('raw', 'JJ'),
#   ('red', 'JJ'),
#   ('cherry', 'NN'),
#   ('aromas', 'VBP'),
#   ('briny', 'JJ'),
#   ('note', 'NN')],
#  [('vineyard', 'NN'),
#   ('designate', 'NN'),
#   ('full', 'JJ'),
#   ('site', 'NN'),
#   ('juicy', 'NN'),
#   ('plum', 'NN'),
#   ('2', 'CD'),
#   ('tobacco', 'NN'),
#   ('bodied', 'VBD'),
#   ('hit', 'JJ'),
#   ('puckering', 'VBG'),
#   ('tannin', 'JJ'),
#   ('oak', 'NN'),
#   ('raspberry', 'NN'),
#   ('cedar', 'NN'),
#   ('meet', 'NN'),
#   ('000', 'CD'),
#   ('feet', 'NNS'),
#   ('high', 'JJ'),
#   ('way', 'NN'),
#   ('boldness', 'NN'),
#   ('wine', 'NN'),
#   ('still', 'RB'),
#   ('youthfully', 'RB'),
#   ('wrapped', 'VBN'),
#   ('pencil', 'NN'),
#   ('lead', 'NN')],
#  [('lightness', 'NN'),
#   ('first', 'RB'),
#   ('release', 'VB'),
#   ('wine', 'JJ'),
#   ('producer', 'NN'),
#   ('tart', 'NN'),
#   ('cranberry', 'NN'),
#   ('add', 'VBP'),
#   ('overall', 'JJ'),
#   ('sense', 'NN'),
#   ('understatement', 'JJ'),
#   ('fruity', 'NN'),
#   ('aromas', 'NN'),
#   ('plum', 'NN')],
#  [('juicy', 'NN'),
#   ('malbec', 'NN'),
#   ('ripeness', 'NN'),
#   ('around', 'IN'),
#   ('integrated', 'JJ'),
#   ('oak', 'NN'),
#   ('small', 'JJ'),
#   ('additions', 'NNS'),
#   ('made', 'VBN'),
#   ('raisiny', 'JJ'),
#   ('quality', 'NN'),
#   ('generous', 'JJ'),
#   ('tannin', 'NN'),
#   ('merlot', 'NN'),
#   ('reveals', 'NNS'),
#   ('equal', 'JJ'),
#   ('parts', 'NNS'),
#   ('cabernet', 'NN'),
#   ('franc', 'NN')],
#  [('earthy', 'JJ'),
#   ('pollen', 'NN'),
#   ('soft', 'JJ'),
#   ('mineral', 'NN'),
#   ('notes', 'NNS'),
#   ('lend', 'VBP'),
#   ('intensified', 'JJ'),
#   ('medium', 'NN'),
#   ('sweet', 'NN'),
#   ('riesling', 'VBG'),
#   ('slightly', 'RB'),
#   ('pulpy', 'JJ'),
#   ('drink', 'VBP'),
#   ('stone', 'NN'),
#   ('fruit', 'NN'),
#   ('flavors', 'NNS'),
#   ('overripe', 'VBP'),
#   ('tangerine', 'JJ'),
#   ('savory', 'NN'),
#   ('tone', 'NN'),
#   ('2018', 'CD')],
#  [('easy', 'JJ'),
#   ('finish', 'JJ'),
#   ('ease', 'NN'),
#   ('similar', 'JJ'),
#   ('notes', 'NNS'),
#   ('medium', 'NN'),
#   ('drink', 'NN'),
#   ('roasted', 'VBD'),
#   ('cashew', 'NN'),
#   ('bodied', 'VBN'),
#   ('chardonnay', 'NN'),
#   ('features', 'NNS'),
#   ('aromas', 'VBP'),
#   ('nuts', 'NNS'),
#   ('mark', 'NN'),
#   ('ripe', 'VBP'),
#   ('pineapple', 'NN'),
#   ('rather', 'RB'),
#   ('soft', 'JJ'),
#   ('palate', 'NN')],
#  [('fruity', 'NN'),
#   ('bleeding', 'VBG'),
#   ('juice', 'NN'),
#   ('case', 'NN'),
#   ('simple', 'JJ'),
#   ('pleasant', 'NN'),
#   ('lightly', 'RB'),
#   ('candied', 'VBD'),
#   ('strawberry', 'JJ'),
#   ('flavors', 'NNS'),
#   ('one', 'CD'),
#   ('might', 'MD'),
#   ('expect', 'VB'),
#   ('made', 'VBN'),
#   ('simply', 'RB'),
#   ('wine', 'JJ'),
#   ('drink', 'VBP'),
#   ('fermenter', 'RBR'),
#   ('whether', 'IN'),
#   ('technique', 'NN'),
#   ('rosés', 'NN'),
#   ('concentrate', 'NN'),
#   ('undemanding', 'NN'),
#   ('remaining', 'VBG')],
#  [('grape', 'NN'),
#   ('black', 'JJ'),
#   ('fruits', 'NNS'),
#   ('light', 'JJ'),
#   ('tannins', 'NNS'),
#   ('sandy', 'JJ'),
#   ('soil', 'NN'),
#   ('grown', 'VBN'),
#   ('open', 'JJ'),
#   ('wine', 'NN'),
#   ('ready', 'JJ'),
#   ('drink', 'VB'),
#   ('typically', 'RB'),
#   ('soft', 'JJ'),
#   ('accessible', 'JJ'),
#   ('—', 'NN'),
#   ('tejo', 'NN')],
#  [('barrel', 'NN'),
#   ('oaky', 'MD'),
#   ('makeup', 'VB'),
#   ('heavy', 'JJ'),
#   ('nose', 'JJ'),
#   ('feels', 'NNS'),
#   ('finishes', 'NNS'),
#   ('center', 'VBP'),
#   ('bit', 'NN'),
#   ('choppy', 'JJ'),
#   ('caramelized', 'VBN'),
#   ('oak', 'RB'),
#   ('forced', 'VBN'),
#   ('woody', 'NN'),
#   ('flavor', 'NN'),
#   ('lot', 'NN'),
#   ('astringent', 'NN'),
#   ('tannins', 'VBZ'),
#   ('herbal', 'JJ'),
#   ('salty', 'NN'),
#   ('plum', 'NN'),
#   ('flavors', 'NNS'),
#   ('wear', 'VBP'),
#   ('front', 'JJ'),
#   ('vanilla', 'NN'),
#   ('aromas', 'NN')],
#  [('oily', 'RB'),
#   ('mature', 'NN'),
#   ('aromas', 'JJ'),
#   ('grape', 'NN'),
#   ('short', 'JJ'),
#   ('free', 'JJ'),
#   ('flow', 'NN'),
#   ('briny', 'NN'),
#   ('leesy', 'JJ'),
#   ('flavors', 'NNS'),
#   ('lack', 'VBP'),
#   ('pop', 'JJ'),
#   ('drink', 'NN'),
#   ('immediately', 'RB'),
#   ('albariño', 'JJ'),
#   ('white', 'JJ'),
#   ('fruits', 'NNS'),
#   ('feels', 'NNS'),
#   ('round', 'VBP'),
#   ('wait', 'JJ'),
#   ('region', 'NN'),
#   ('grabby', 'NN'),
#   ('aged', 'VBD'),
#   ('finish', 'JJ'),
#   ('newer', 'JJR'),
#   ('vintage', 'NN'),
#   ('weak', 'JJ'),
#   ('side', 'NN'),
#   ('precision', 'NN'),
#   ('bland', 'NN'),
#   ('known', 'VBN')],
#  [('fruity', 'NN'),
#   ('balancing', 'VBG'),
#   ('acidity', 'NN'),
#   ('ripe', 'NN'),
#   ('apéritif', 'JJ'),
#   ('—', 'NNP'),
#   ('light', 'NN'),
#   ('refreshing', 'VBG'),
#   ('perfect', 'JJ'),
#   ('great', 'JJ'),
#   ('apricot', 'JJ'),
#   ('pineapple', 'NN'),
#   ('fruit', 'NN'),
#   ('hints', 'NNS'),
#   ('drink', 'VBP'),
#   ('sweet', 'JJ'),
#   ('wine', 'NN'),
#   ('spicy', 'NN'),
#   ('wood', 'NN'),
#   ('immediately', 'RB'),
#   ('attractive', 'JJ')],
#  [('summertime', 'JJ'),
#   ('refreshment', 'NN'),
#   ('body', 'NN'),
#   ('palate', 'JJ'),
#   ('delivers', 'NNS'),
#   ('nuances', 'NNS'),
#   ('crisp', 'VBP'),
#   ('wine', 'JJ'),
#   ('exudes', 'NNS'),
#   ('passion', 'NN'),
#   ('fruit', 'NN'),
#   ('hue', 'NN'),
#   ('muskmelon', 'NN'),
#   ('medium', 'NN'),
#   ('drink', 'VBP'),
#   ('racy', 'NN'),
#   ('nose', 'RB'),
#   ('well', 'RB'),
#   ('perfectly', 'RB'),
#   ('suited', 'VBN'),
#   ('pale', 'JJ'),
#   ('copper', 'NN')],
#  [('soft', 'JJ'),
#   ('13', 'CD'),
#   ('wine', 'NN'),
#   ('richly', 'RB'),
#   ('conceived', 'VBN'),
#   ('combination', 'NN'),
#   ('mocha', 'NN'),
#   ('supple', 'JJ'),
#   ('smoky', 'JJ'),
#   ('black', 'JJ'),
#   ('fruit', 'NN'),
#   ('healthy', 'JJ'),
#   ('addition', 'NN'),
#   ('petite', 'JJ'),
#   ('sirah', 'NN'),
#   ('provides', 'VBZ'),
#   ('added', 'JJ'),
#   ('weight', 'NN'),
#   ('intensity', 'NN')],
#  [('finish', 'JJ'),
#   ('pollen', 'NN'),
#   ('pronounced', 'VBD'),
#   ('dust', 'JJ'),
#   ('racy', 'NN'),
#   ('acidity', 'NN'),
#   ('fresh', 'JJ'),
#   ('tangerine', 'NN'),
#   ('lemon', 'NN'),
#   ('flavors', 'NNS'),
#   ('turn', 'VBP'),
#   ('herbal', 'JJ'),
#   ('drink', 'VBP'),
#   ('otherwise', 'RB'),
#   ('citrusy', 'JJ'),
#   ('wine', 'NN'),
#   ('earth', 'NN'),
#   ('tones', 'NNS'),
#   ('lend', 'VBP'),
#   ('savoriness', 'NN')],
#  [('ripe', 'JJ'),
#   ('pear', 'JJ'),
#   ('dry', 'JJ'),
#   ('palate', 'NN'),
#   ('lean', 'JJ'),
#   ('fruit', 'NN'),
#   ('flavors', 'NNS'),
#   ('vibrant', 'VBP'),
#   ('aromas', 'NN'),
#   ('followed', 'VBD'),
#   ('white', 'JJ'),
#   ('flowers', 'NNS'),
#   ('melon', 'NN')],
#  [('designate', 'NN'),
#   ('herbal', 'JJ'),
#   ('approach', 'NN'),
#   ('leather', 'NN'),
#   ('dotted', 'VBD'),
#   ('baked', 'JJ'),
#   ('cherry', 'NN'),
#   ('light', 'NN'),
#   ('softened', 'VBD'),
#   ('tannins', 'NNS'),
#   ('surround', 'JJ'),
#   ('lean', 'JJ'),
#   ('vineyard', 'NN'),
#   ('black', 'JJ'),
#   ('pepper', 'NN'),
#   ('bodied', 'VBD')],
#  [('acacia', 'NN'),
#   ('waft', 'NN'),
#   ('french', 'JJ'),
#   ('oak', 'NN'),
#   ('fruit', 'NN'),
#   ('richness', 'NN'),
#   ('racy', 'NN'),
#   ('acidity', 'NN'),
#   ('hint', 'NN'),
#   ('glass', 'NN'),
#   ('toast', 'NN'),
#   ('citrus', 'NN'),
#   ('set', 'VBN'),
#   ('driven', 'JJ'),
#   ('spice', 'NN'),
#   ('rather', 'RB'),
#   ('shy', 'JJ'),
#   ('lean', 'JJ'),
#   ('palate', 'NN'),
#   ('offers', 'NNS'),
#   ('subdued', 'VBD'),
#   ('aromas', 'RB'),
#   ('chopped', 'VBN'),
#   ('herb', 'NN')],
#  [('malvasia', 'NN'),
#   ('bread', 'NN'),
#   ('dough', 'IN'),
#   ('honeydew', 'NN'),
#   ('melon', 'NN'),
#   ('marks', 'NNS'),
#   ('bright', 'VBD'),
#   ('white', 'JJ'),
#   ('grapes', 'NNS'),
#   ('pastry', 'NN'),
#   ('cream', 'NN'),
#   ('enjoyable', 'JJ'),
#   ('palate', 'NN'),
#   ('offers', 'NNS'),
#   ('ripe', 'VBP'),
#   ('cherry', 'NN'),
#   ('red', 'JJ'),
#   ('berry', 'NN'),
#   ('yeasty', 'NN'),
#   ('whiff', 'NN'),
#   ('made', 'VBD'),
#   ('primarily', 'RB'),
#   ('sangiovese', 'JJ'),
#   ('hint', 'NN'),
#   ('close', 'JJ'),
#   ('note', 'NN'),
#   ('aromas', 'NN')],
#  [('malbec', 'NN'),
#   ('soft', 'JJ'),
#   ('wealth', 'NN'),
#   ('ripe', 'NN'),
#   ('richly', 'RB'),
#   ('round', 'NN'),
#   ('shows', 'VBZ'),
#   ('blend', 'VBP'),
#   ('lightly', 'RB'),
#   ('oaked', 'VBN'),
#   ('type', 'NN'),
#   ('approachable', 'JJ'),
#   ('petite', 'JJ'),
#   ('sirah', 'NN'),
#   ('sangiovese', 'JJ'),
#   ('cabernet', 'NN'),
#   ('sauvignon', 'NN'),
#   ('varieties', 'NNS'),
#   ('plays', 'VBZ'),
#   ('well', 'RB'),
#   ('dusty', 'JJ'),
#   ('black', 'JJ'),
#   ('fruit', 'NN'),
#   ('palate', 'NN')],
#  [('lightness', 'NN'),
#   ('perceptible', 'JJ'),
#   ('sweetness', 'NN'),
#   ('body', 'NN'),
#   ('touch', 'JJ'),
#   ('apricot', 'JJ'),
#   ('coastal', 'JJ'),
#   ('crisp', 'NN'),
#   ('wine', 'NN'),
#   ('grown', 'VBN'),
#   ('variety', 'NN'),
#   ('showing', 'VBG'),
#   ('guava', 'JJ'),
#   ('wrap', 'NN'),
#   ('around', 'RB'),
#   ('tropical', 'JJ'),
#   ('nose', 'JJ'),
#   ('texture', 'NN'),
#   ('yet', 'RB'),
#   ('tastes', 'VBZ'),
#   ('dry', 'JJ'),
#   ('melon', 'NN'),
#   ('straightforward', 'NN'),
#   ('approach', 'NN')],
#  [('red', 'JJ'),
#   ('bordeaux', 'NN'),
#   ('varieties', 'NNS'),
#   ('touch', 'VBP'),
#   ('petit', 'JJ'),
#   ('verdot', 'NN'),
#   ('leather', 'NN'),
#   ('except', 'IN'),
#   ('cedar', 'NN'),
#   ('tobacco', 'NN'),
#   ('ripe', 'NN'),
#   ('offer', 'NN'),
#   ('chewiness', 'NN'),
#   ('full', 'JJ'),
#   ('bodied', 'VBN'),
#   ('together', 'RB'),
#   ('bold', 'JJ'),
#   ('brawny', 'NN'),
#   ('wine', 'NN'),
#   ('simple', 'JJ'),
#   ('tannic', 'JJ'),
#   ('structure', 'NN'),
#   ('represented', 'VBN'),
#   ('blend', 'NN'),
#   ('strengthens', 'NNS')],
#  [('ivy', 'NN'),
#   ('leaves', 'VBZ'),
#   ('easy', 'JJ'),
#   ('drinking', 'VBG'),
#   ('flavors', 'NNS'),
#   ('fresh', 'JJ'),
#   ('freshness', 'NN'),
#   ('characterizes', 'VBZ'),
#   ('charming', 'VBG'),
#   ('palate', 'JJ'),
#   ('drink', 'NN'),
#   ('soon', 'RB'),
#   ('light', 'VBD'),
#   ('footed', 'VBN'),
#   ('nose', 'JJ'),
#   ('citrus', 'NN'),
#   ('notes', 'NNS'),
#   ('play', 'VBP'),
#   ('green', 'JJ'),
#   ('pear', 'NN')],
#  [('creamsicle', 'NN'),
#   ('barrel', 'NN'),
#   ('flavors', 'NNS'),
#   ('baking', 'VBG'),
#   ('spice', 'NN'),
#   ('notes', 'NNS'),
#   ('get', 'VBP'),
#   ('broad', 'JJ'),
#   ('times', 'NNS'),
#   ('stone', 'VBP'),
#   ('prominent', 'JJ'),
#   ('fruit', 'NN'),
#   ('dry', 'JJ'),
#   ('provides', 'VBZ'),
#   ('intrigue', 'JJ'),
#   ('way', 'NN'),
#   ('wood', 'NN'),
#   ('seems', 'VBZ'),
#   ('aromas', 'JJ'),
#   ('palate', 'NN')],
#  [('concentrated', 'VBN'),
#   ('cru', 'JJ'),
#   ('wine', 'NN'),
#   ('rich', 'JJ'),
#   ('potential', 'JJ'),
#   ('drink', 'NN'),
#   ('packed', 'VBN'),
#   ('appellation', 'NN'),
#   ('acidity', 'NN'),
#   ('dense', 'NN'),
#   ('dark', 'JJ'),
#   ('mineral', 'JJ'),
#   ('texture', 'NN'),
#   ('brings', 'VBZ'),
#   ('tannins', 'NNS'),
#   ('ageworthiness', 'JJ'),
#   ('2018', 'CD')],
#  [('ripe', 'JJ'),
#   ('fruity', 'NN'),
#   ('wine', 'NN'),
#   ('attractive', 'JJ'),
#   ('red', 'JJ'),
#   ('berry', 'NN'),
#   ('flavors', 'NNS'),
#   ('finished', 'VBD'),
#   ('one', 'CD'),
#   ('ready', 'NN'),
#   ('accessible', 'JJ'),
#   ('drink', 'NN'),
#   ('comes', 'VBZ'),
#   ('crisp', 'JJ'),
#   ('acidity', 'NN'),
#   ('cru', 'NN'),
#   ('estates', 'VBZ'),
#   ('followed', 'VBD'),
#   ('negociant', 'JJ'),
#   ('house', 'NN'),
#   ('light', 'NN')],
#  [('pears', 'NNS'),
#   ('finish', 'JJ'),
#   ('touch', 'JJ'),
#   ('palate', 'NN'),
#   ('otherwise', 'RB'),
#   ('bright', 'JJ'),
#   ('bristling', 'VBG'),
#   ('wine', 'NN'),
#   ('delicate', 'NN'),
#   ('honey', 'NN'),
#   ('tones', 'NNS'),
#   ('register', 'RBR'),
#   ('drink', 'VBP'),
#   ('freshly', 'RB'),
#   ('pressed', 'VBN'),
#   ('apples', 'NNS'),
#   ('nose', 'RB'),
#   ('balance', 'NN'),
#   ('neatly', 'RB'),
#   ('alongside', 'JJ'),
#   ('flavors', 'NNS'),
#   ('marked', 'VBD'),
#   ('pencil', 'JJ'),
#   ('lead', 'NN'),
#   ('dry', 'JJ'),
#   ('2020', 'CD'),
#   ('savory', 'NN'),
#   ('tone', 'NN'),
#   ('wisp', 'NN'),
#   ('bramble', 'JJ'),
#   ('extends', 'NNS')],
#  [('menthol', 'NN'),
#   ('drink', 'VB'),
#   ('sooner', 'JJR'),
#   ('rather', 'RB'),
#   ('capture', 'NN'),
#   ('later', 'RBR'),
#   ('espresso', 'NN'),
#   ('cranberry', 'NN'),
#   ('glass', 'NN'),
#   ('forest', 'JJS'),
#   ('floor', 'NN'),
#   ('lean', 'JJ'),
#   ('linear', 'JJ'),
#   ('palate', 'NN'),
#   ('shows', 'NNS'),
#   ('dried', 'VBD'),
#   ('sour', 'JJ'),
#   ('cherry', 'NN'),
#   ('pressed', 'VBD'),
#   ('violet', 'NN'),
#   ('aromas', 'NNS'),
#   ('take', 'VBP'),
#   ('shape', 'NN'),
#   ('even', 'RB'),
#   ('though', 'IN'),
#   ('coffee', 'NN'),
#   ('bean', 'NN'),
#   ('alongside', 'RB'),
#   ('assertive', 'JJ'),
#   ('close', 'RB'),
#   ('remaining', 'VBG'),
#   ('fruit', 'NN'),
#   ('licorice', 'NN'),
#   ('grained', 'VBD'),
#   ('tannins', 'NNS'),
#   ('still', 'RB'),
#   ('firm', 'VBP')],
#  [('juicy', 'NN'),
#   ('fruity', 'NN'),
#   ('core', 'NN'),
#   ('plummy', 'NN'),
#   ('flavor', 'NN'),
#   ('soft', 'JJ'),
#   ('elegantly', 'RB'),
#   ('complements', 'NNS'),
#   ('showing', 'VBG'),
#   ('grapy', 'NN'),
#   ('tobacco', 'NN'),
#   ('bordeaux', 'NN'),
#   ('varieties', 'NNS'),
#   ('graphite', 'VBP'),
#   ('blends', 'VBZ'),
#   ('20', 'CD'),
#   ('tar', 'NN'),
#   ('savory', 'NN'),
#   ('ending', 'VBG'),
#   ('simply', 'RB'),
#   ('five', 'CD'),
#   ('red', 'JJ'),
#   ('palate', 'NN')],
#  [('satisfying', 'VBG'),
#   ('white', 'JJ'),
#   ('2019', 'CD'),
#   ('pear', 'JJ'),
#   ('flavors', 'NNS'),
#   ('bodied', 'VBD'),
#   ('pinot', 'JJ'),
#   ('gris', 'JJ'),
#   ('full', 'JJ'),
#   ('bit', 'NN'),
#   ('creamy', 'JJ'),
#   ('fresh', 'JJ'),
#   ('apple', 'NN'),
#   ('mouthfeel', 'NN'),
#   ('yet', 'RB'),
#   ('balanced', 'VBN'),
#   ('briskly', 'JJ'),
#   ('wide', 'JJ'),
#   ('pairing', 'VBG'),
#   ('appeal', 'JJ'),
#   ('lemon', 'NN'),
#   ('accented', 'VBD'),
#   ('drink', 'NN'),
#   ('smoked', 'VBD'),
#   ('nuts', 'NNS'),
#   ('bold', 'JJ'),
#   ('hint', 'NN'),
#   ('rich', 'JJ')],
#  [('struck', 'JJ'),
#   ('flint', 'JJ'),
#   ('lend', 'NN'),
#   ('style', 'NN'),
#   ('palate', 'NN'),
#   ('offers', 'NNS'),
#   ('delicately', 'RB'),
#   ('concentrated', 'VBD'),
#   ('flavors', 'NNS'),
#   ('tangerine', 'VBP'),
#   ('acidity', 'NN'),
#   ('bodied', 'VBN'),
#   ('riesling', 'VBG'),
#   ('dusty', 'JJ'),
#   ('mineral', 'NN'),
#   ('drink', 'NN'),
#   ('lean', 'JJ'),
#   ('light', 'NN'),
#   ('red', 'JJ'),
#   ('apple', 'NN'),
#   ('set', 'VBN'),
#   ('dry', 'JJ'),
#   ('smoke', 'NN'),
#   ('nectarine', 'JJ'),
#   ('savory', 'NN'),
#   ('tone', 'NN'),
#   ('2021', 'CD')],
#  [('otherwise', 'RB'),
#   ('bright', 'JJ'),
#   ('nimble', 'JJ'),
#   ('riesling', 'VBG'),
#   ('palate', 'NN'),
#   ('boasts', 'NNS'),
#   ('freshly', 'RB'),
#   ('pressed', 'VBN'),
#   ('apple', 'NN'),
#   ('pear', 'JJ'),
#   ('flavors', 'NNS'),
#   ('accentuated', 'VBD'),
#   ('struck', 'JJ'),
#   ('flint', 'NN'),
#   ('intensely', 'RB'),
#   ('smoky', 'JJ'),
#   ('tones', 'NNS'),
#   ('ash', 'VBP'),
#   ('extend', 'VBP'),
#   ('throughout', 'IN'),
#   ('zippy', 'JJ'),
#   ('lemon', 'JJ'),
#   ('drink', 'NN'),
#   ('lime', 'NN'),
#   ('acidity', 'NN'),
#   ('2021', 'CD')],
#  [('mild', 'JJ'),
#   ('oak', 'NN'),
#   ('salty', 'NN'),
#   ('bright', 'VBD'),
#   ('nose', 'JJ'),
#   ('citric', 'JJ'),
#   ('aromas', 'NN'),
#   ('comes', 'VBZ'),
#   ('edges', 'VBZ'),
#   ('apple', 'NN'),
#   ('lightly', 'RB'),
#   ('oaked', 'VBD'),
#   ('nectarine', 'JJ'),
#   ('flavors', 'NNS'),
#   ('composition', 'VBP'),
#   ('green', 'JJ'),
#   ('acidic', 'JJ'),
#   ('racy', 'NN'),
#   ('roundness', 'NN'),
#   ('along', 'RB'),
#   ('high', 'JJ'),
#   ('acid', 'IN'),
#   ('finish', 'JJ'),
#   ('holds', 'VBZ'),
#   ('form', 'NN'),
#   ('palate', 'NN')],
#  [('black', 'JJ'),
#   ('thyme', 'NN'),
#   ('65', 'CD'),
#   ('easygoing', 'VBG'),
#   ('palate', 'NN'),
#   ('delivers', 'NNS'),
#   ('cherry', 'VBP'),
#   ('made', 'VBN'),
#   ('skinned', 'VBD'),
#   ('fruit', 'JJ'),
#   ('15', 'CD'),
#   ('merlot', 'NN'),
#   ('cinnamon', 'NN'),
#   ('alongside', 'IN'),
#   ('smooth', 'JJ'),
#   ('tannins', 'NNS'),
#   ('sangiovese', 'JJ'),
#   ('cabernet', 'NN'),
#   ('sauvignon', 'VBD'),
#   ('20', 'CD'),
#   ('subtle', 'JJ'),
#   ('aromas', 'NN')],
#  [('malvasia', 'NN'),
#   ('inviting', 'VBG'),
#   ('aromas', 'NNS'),
#   ('made', 'VBN'),
#   ('predominantly', 'RB'),
#   ('pinot', 'JJ'),
#   ('grigio', 'NN'),
#   ('citrus', 'NN'),
#   ('round', 'NN'),
#   ('fruity', 'NN'),
#   ('palate', 'NN'),
#   ('doles', 'NNS'),
#   ('along', 'IN'),
#   ('bianco', 'NN'),
#   ('ripe', 'NN'),
#   ('orchard', 'NN'),
#   ('fruit', 'NN'),
#   ('apricot', 'NN'),
#   ('orange', 'NN'),
#   ('zest', 'NN'),
#   ('juicy', 'NN'),
#   ('pineapple', 'NN'),
#   ('trebbiano', 'NN'),
#   ('riesling', 'VBG'),
#   ('renano', 'NN')],
#  [('dark', 'JJ'),
#   ('espresso', 'NN'),
#   ('hint', 'NN'),
#   ('cabernet', 'NN'),
#   ('franc', 'NN'),
#   ('polished', 'VBD'),
#   ('tannins', 'NNS'),
#   ('whiff', 'JJ'),
#   ('bodied', 'VBD'),
#   ('pleasant', 'JJ'),
#   ('red', 'JJ'),
#   ('straightforward', 'NN'),
#   ('palate', 'NN'),
#   ('offers', 'NNS'),
#   ('cherry', 'VBP'),
#   ('skinned', 'VBN'),
#   ('fruit', 'NN'),
#   ('sangiovese', 'JJ'),
#   ('blend', 'NN'),
#   ('sauvignon', 'NN'),
#   ('light', 'JJ'),
#   ('spice', 'NN'),
#   ('alongside', 'RB'),
#   ('zesty', 'JJ'),
#   ('acidity', 'NN'),
#   ('toast', 'NN'),
#   ('merlot', 'NN'),
#   ('currant', 'NN'),
#   ('aromas', 'NN')],
#  [('yellow', 'JJ'),
#   ('stone', 'NN'),
#   ('fruit', 'NN'),
#   ('glass', 'NN'),
#   ('white', 'JJ'),
#   ('spring', 'NN'),
#   ('flower', 'NN'),
#   ('peach', 'NN'),
#   ('soft', 'JJ'),
#   ('round', 'NN'),
#   ('palate', 'NN'),
#   ('offers', 'NNS'),
#   ('ripe', 'VBP'),
#   ('apricot', 'RB'),
#   ('candied', 'VBN'),
#   ('nectarine', 'JJ'),
#   ('zest', 'JJS'),
#   ('whiff', 'NN'),
#   ('hint', 'NN'),
#   ('citrus', 'NN'),
#   ('lift', 'NN'),
#   ('aromas', 'NN')],
#  [('coyote', 'NN'),
#   ('mint', 'NN'),
#   ('thyme', 'JJ'),
#   ('lots', 'NNS'),
#   ('blackberry', 'VBP'),
#   ('fruit', 'NN'),
#   ('cedar', 'NN'),
#   ('dr', 'NN'),
#   ('pepper', 'NN'),
#   ('spice', 'NN'),
#   ('oregano', 'IN'),
#   ('showing', 'VBG'),
#   ('finishing', 'JJ'),
#   ('grape', 'NN'),
#   ('wine', 'NN'),
#   ('spearmint', 'NN'),
#   ('sip', 'NN'),
#   ('ginger', 'NN'),
#   ('snaps', 'NNS'),
#   ('dill', 'VB'),
#   ('hot', 'JJ'),
#   ('licorice', 'NN'),
#   ('herbal', 'JJ'),
#   ('take', 'NN'),
#   ('provides', 'VBZ'),
#   ('sweet', 'JJ'),
#   ('cherry', 'NN'),
#   ('strawberry', 'VBP'),
#   ('marjoram', 'NNS'),
#   ('make', 'VBP'),
#   ('backbone', 'NN')],
#  [('opens', 'NNS'),
#   ('silky', 'VBP'),
#   ('tannins', 'NNS'),
#   ('herb', 'JJ'),
#   ('coffee', 'NN'),
#   ('alongside', 'NN'),
#   ('bright', 'JJ'),
#   ('acidity', 'NN'),
#   ('hint', 'NN'),
#   ('roasted', 'VBD'),
#   ('bean', 'JJ'),
#   ('red', 'JJ'),
#   ('berry', 'NN'),
#   ('soft', 'JJ'),
#   ('palate', 'NN'),
#   ('offers', 'NNS'),
#   ('black', 'JJ'),
#   ('cherry', 'NN'),
#   ('mocha', 'NN'),
#   ('toast', 'NN'),
#   ('drink', 'NN'),
#   ('merlot', 'NN'),
#   ('easy', 'JJ'),
# ...
#  [('bulging', 'VBG'),
#   ('muscle', 'NN'),
#   ('noticeable', 'JJ'),
#   ('feature', 'NN'),
#   ('heavy', 'JJ'),
#   ('comes', 'VBZ'),
#   ('exaggerate', 'JJ'),
#   ('syrupy', 'NNS'),
#   ('brawny', 'VBP'),
#   ('wine', 'NN'),
#   ('delivers', 'NNS'),
#   ('power', 'NN'),
#   ('wood', 'NN'),
#   ('element', 'NN'),
#   ('knocks', 'NNS'),
#   ('every', 'DT'),
#   ('way', 'NN'),
#   ('possible', 'JJ'),
#   ('sweet', 'JJ'),
#   ('tasting', 'VBG'),
#   ('fresh', 'JJ'),
#   ('carpentry', 'NN'),
#   ('shavings', 'NNS'),
#   ('oversized', 'VBD'),
#   ('black', 'JJ'),
#   ('bottle', 'NN'),
#   ('packaged', 'VBD'),
#   ('face', 'NN'),
#   ('aromas', 'NN')],
#  [('kono', 'NN'),
#   ('light', 'JJ'),
#   ('side', 'NN'),
#   ('gives', 'VBZ'),
#   ('15', 'CD'),
#   ('2008', 'CD'),
#   ('priced', 'VBN'),
#   ('2004', 'CD'),
#   ('zippy', 'JJ'),
#   ('tart', 'JJ'),
#   ('wine', 'NN'),
#   ('idea', 'NN'),
#   ('drink', 'VBP'),
#   ('fast', 'JJ'),
#   ('pineapple', 'JJ'),
#   ('supply', 'NN'),
#   ('herbal', 'JJ'),
#   ('overtones', 'NNS'),
#   ('2005', 'CD'),
#   ('vintages', 'NNS'),
#   ('refreshing', 'VBG'),
#   ('aspect', 'JJ'),
#   ('marlborough', 'NN'),
#   ('sauvignon', 'NN'),
#   ('blanc', 'NN'),
#   ('increased', 'VBD'),
#   ('grapefruit', 'NN'),
#   ('flavors', 'NNS')],
#  [('fruity', 'NN'),
#   ('tropical', 'JJ'),
#   ('citrus', 'NN'),
#   ('wine', 'NN'),
#   ('holds', 'VBZ'),
#   ('touch', 'JJ'),
#   ('banana', 'JJ'),
#   ('flavors', 'NNS'),
#   ('palate', 'VBP'),
#   ('slightly', 'RB'),
#   ('oily', 'RB'),
#   ('apple', 'NN'),
#   ('good', 'JJ'),
#   ('acidity', 'NN'),
#   ('mango', 'VBP'),
#   ('sweet', 'JJ'),
#   ('overall', 'JJ'),
#   ('drink', 'NN'),
#   ('right', 'RB'),
#   ('away', 'RB'),
#   ('plump', 'VB'),
#   ('together', 'RB'),
#   ('buttercup', 'JJ'),
#   ('aromas', 'NNS'),
#   ('light', 'NN')],
#  [('fresh', 'JJ'),
#   ('verona', 'NNS'),
#   ('area', 'NN'),
#   ('sipping', 'VBG'),
#   ('rosé', 'NN'),
#   ('lively', 'RB'),
#   ('white', 'JJ'),
#   ('cherry', 'JJ'),
#   ('wine', 'NN'),
#   ('awards', 'NNS'),
#   ('pretty', 'RB'),
#   ('aromas', 'VBP'),
#   ('northern', 'JJ'),
#   ('italy', 'JJ'),
#   ('—', 'NNS'),
#   ('make', 'VBP'),
#   ('dindarella', 'NN'),
#   ('three', 'CD'),
#   ('grapes', 'NNS'),
#   ('native', 'JJ'),
#   ('raspberry', 'VBP'),
#   ('corvina', 'JJ'),
#   ('rondinella', 'NN'),
#   ('easy', 'NN')],
#  [('wade', 'NN'),
#   ('lively', 'RB'),
#   ('herbal', 'JJ'),
#   ('snap', 'NN'),
#   ('common', 'JJ'),
#   ('also', 'RB'),
#   ('bramble', 'JJ'),
#   ('red', 'JJ'),
#   ('fruit', 'NN'),
#   ('good', 'JJ'),
#   ('introductory', 'NN'),
#   ('carmenère', 'NN'),
#   ('quality', 'NN'),
#   ('level', 'NN'),
#   ('mild', 'VBP'),
#   ('burnt', 'JJ'),
#   ('aromas', 'NNS'),
#   ('touch', 'JJ'),
#   ('green', 'JJ'),
#   ('clanky', 'NN'),
#   ('expecting', 'VBG'),
#   ('coconut', 'NN'),
#   ('much', 'JJ'),
#   ('palate', 'NN')],
#  [('currant', 'JJ'),
#   ('little', 'JJ'),
#   ('tough', 'JJ'),
#   ('finish', 'NN'),
#   ('okay', 'NN'),
#   ('shows', 'VBZ'),
#   ('blackberry', 'VBP'),
#   ('gritty', 'JJ'),
#   ('tobacco', 'NN'),
#   ('everyday', 'JJ'),
#   ('fare', 'NN'),
#   ('herb', 'NN'),
#   ('flavors', 'NNS'),
#   ('turn', 'VBP'),
#   ('sweetly', 'RB'),
#   ('fruity', 'NN')],
#  [('fresh', 'JJ'),
#   ('easily', 'RB'),
#   ('lively', 'RB'),
#   ('champagne', 'JJ'),
#   ('although', 'IN'),
#   ('delicious', 'JJ'),
#   ('acidity', 'NN'),
#   ('sweeter', 'RBR'),
#   ('festive', 'JJ'),
#   ('little', 'JJ'),
#   ('pink', 'JJ'),
#   ('bottle', 'NN'),
#   ('labeled', 'VBD'),
#   ('“', 'JJ'),
#   ('extra', 'JJ'),
#   ('dry', 'JJ'),
#   ('”', 'NNP'),
#   ('brut', 'NN'),
#   (')', ')'),
#   (',', ','),
#   ('finishes', 'VBZ'),
#   ('lightly', 'RB')],
#  [('crisp', 'NN'),
#   ('acidity', 'NN'),
#   ('fortunately', 'RB'),
#   ('provides', 'VBZ'),
#   ('even', 'RB'),
#   ('richer', 'JJR'),
#   ('notes', 'NNS'),
#   ('sweet', 'JJ'),
#   ('balance', 'NN'),
#   ('buttered', 'VBD'),
#   ('toast', 'JJ'),
#   ('venge', 'NN'),
#   ('vineyards', 'NNS'),
#   ('smoky', 'VBP'),
#   ('vanilla', 'NN'),
#   ('jammy', 'NN'),
#   ('apricots', 'NNS'),
#   ('pineapples', 'NNS')],
#  [('soft', 'JJ'),
#   ('tannin', 'NN'),
#   ('structure', 'NN'),
#   ('could', 'MD'),
#   ('cocoa', 'VB'),
#   ('fruit', 'JJ'),
#   ('flavors', 'NNS'),
#   ('bit', 'VBP'),
#   ('earthy', 'JJ'),
#   ('firmer', 'JJR'),
#   ('acidity', 'NN'),
#   ('cherry', 'NN'),
#   ('herbal', 'NN')],
#  [('rather', 'RB'),
#   ('bitter', 'JJ'),
#   ('toast', 'JJ'),
#   ('finish', 'JJ'),
#   ('soft', 'JJ'),
#   ('slightly', 'RB'),
#   ('oxidized', 'VBN'),
#   ('pleasantly', 'RB'),
#   ('quaffable', 'JJ'),
#   ('generic', 'NN'),
#   ('marked', 'VBD')],
#  [('fabio', 'NN'),
#   ('sireci', 'JJ'),
#   ('mediterranean', 'JJ'),
#   ('island', 'NN'),
#   (')', ')'),
#   (',', ','),
#   ('ending', 'VBG'),
#   ('tad', 'NNS'),
#   ('jammy', 'JJ'),
#   ('results', 'NNS'),
#   ('ripe', 'JJ'),
#   ('aromas', 'RB'),
#   ('behind', 'IN'),
#   ('smack', 'NN'),
#   ('avola', 'NN'),
#   ('prune', 'NN'),
#   ('raisin', 'VBP'),
#   ('sicily', 'RB'),
#   ('flex', 'JJ'),
#   ('vineyards', 'NNS'),
#   ('pinot', 'VBP'),
#   ('noir', 'RB'),
#   ('muddled', 'VBN'),
#   ('recently', 'RB'),
#   ('decided', 'VBD'),
#   ('middle', 'JJ'),
#   ('winemaker', 'NN'),
#   ('muscle', 'NN'),
#   ('best', 'RBS'),
#   ('nero', 'NN')],
#  [('citrus', 'NN'),
#   ('known', 'VBN'),
#   ('k', 'JJ'),
#   ('clean', 'JJ'),
#   ('blend', 'NN'),
#   ('based', 'VBN'),
#   ('finishes', 'NNS'),
#   ('honey', 'VBP'),
#   ('crisp', 'NN'),
#   ('sauvignon', 'NN'),
#   ('blanc', 'NN'),
#   ('rich', 'JJ'),
#   ('flavors', 'NNS'),
#   ('green', 'JJ'),
#   ('apple', 'NN'),
#   ('vanilla', 'NN'),
#   ('well', 'RB'),
#   ('pear', 'JJ'),
#   ('j', 'NN'),
#   ('sweetness', 'NN')],
#  [('pears', 'NNS'),
#   ('brown', 'JJ'),
#   ('sugar', 'NN'),
#   ('honeysuckle', 'NN'),
#   ('flowers', 'NNS'),
#   ('sweet', 'VBP'),
#   ('pleasantly', 'RB'),
#   ('exotic', 'JJ'),
#   ('flavors', 'NNS'),
#   ('minerals', 'NNS'),
#   ('smoky', 'VBP'),
#   ('oak', 'JJ'),
#   ('drink', 'NN'),
#   ('green', 'JJ'),
#   ('apples', 'NNS'),
#   ('vanilla', 'RB'),
#   ('easy', 'JJ'),
#   ('simple', 'JJ'),
#   ('spices', 'NNS'),
#   ('pineapples', 'NNS')],
#  [('honeysuckle', 'NN'),
#   ('roussanne', 'NN'),
#   ('little', 'RB'),
#   ('loaded', 'JJ'),
#   ('tangerine', 'NN'),
#   ('crisp', 'NN'),
#   ('spicy', 'NN'),
#   ('vanilla', 'NN'),
#   ('flavors', 'NNS'),
#   ('sauvignon', 'VBP'),
#   ('blanc', 'NN'),
#   ('muscat', 'NN'),
#   ('chardonnay', 'NN'),
#   ('acidity', 'NN'),
#   ('grapefruit', 'NN'),
#   ('front', 'JJ'),
#   ('sweet', 'JJ'),
#   ('side', 'NN'),
#   ('pineapple', 'NN')],
#  [('white', 'JJ'),
#   ('currants', 'NNS'),
#   ('fruity', 'NN'),
#   ('certainly', 'RB'),
#   ('fresh', 'JJ'),
#   ('coalesce', 'NNS'),
#   ('right', 'RB'),
#   ('sauvignon', 'VBP'),
#   ('blanc', 'JJ'),
#   ('brings', 'NNS'),
#   ('herbaceous', 'JJ'),
#   ('grassy', 'JJ'),
#   ('heavy', 'JJ'),
#   ('dose', 'NN'),
#   ('needs', 'NNS'),
#   ('front', 'JJ'),
#   ('gooseberry', 'NN'),
#   ('flavors', 'NNS'),
#   ('young', 'JJ'),
#   ('time', 'NN')],
#  [('notes', 'NNS'),
#   ('mouth', 'VBP'),
#   ('mature', 'NN'),
#   ('fruit', 'NN'),
#   ('muddled', 'VBD'),
#   ('natural', 'JJ'),
#   ('rubber', 'NN'),
#   ('wine', 'NN'),
#   ('generally', 'RB'),
#   ('lacks', 'VBZ'),
#   ('definition', 'NN'),
#   ('red', 'JJ'),
#   ('flavors', 'NNS'),
#   ('places', 'NNS'),
#   ('fully', 'RB'),
#   ('evolved', 'VBD'),
#   ('tight', 'JJ'),
#   ('tannins', 'NNS'),
#   ('seem', 'VBP'),
#   ('aromas', 'NNS')],
#  [('whites', 'NNS'),
#   ('totally', 'RB'),
#   ('fresh', 'JJ'),
#   ('wine', 'NN'),
#   ('pink', 'NN'),
#   ('grapefruit', 'NN'),
#   ('flavors', 'NNS'),
#   ('giving', 'VBG'),
#   ('quality', 'NN'),
#   ('benefited', 'VBD'),
#   ('juicy', 'NN'),
#   ('fruits', 'NNS'),
#   ('herbaceousness', 'NN'),
#   ('2007', 'CD'),
#   ('bordeaux', 'NN'),
#   ('intense', 'JJ'),
#   ('lift', 'NN'),
#   ('drink', 'NN'),
#   ('lemony', 'NN'),
#   ('green', 'JJ'),
#   ('herbs', 'NN')],
#  [('northern', 'JJ'),
#   ('italian', 'JJ'),
#   ('cabernet', 'NN'),
#   ('cedar', 'NN'),
#   ('low', 'JJ'),
#   ('intensity', 'NN'),
#   ('ends', 'VBZ'),
#   ('pine', 'JJ'),
#   ('informal', 'JJ'),
#   ('style', 'NN'),
#   ('acidity', 'NN'),
#   ('wine', 'NN'),
#   ('delivers', 'NNS'),
#   ('measured', 'VBD'),
#   ('aromas', 'JJ'),
#   ('cherry', 'NN'),
#   ('crisp', 'JJ'),
#   ('note', 'NN'),
#   ('light', 'NN')],
#  [('sugary', 'JJ'),
#   ('flavors', 'NNS'),
#   ('pears', 'VBZ'),
#   ('flowers', 'NNS'),
#   ('crisp', 'JJ'),
#   ('acidity', 'NN'),
#   ('provides', 'VBZ'),
#   ('needed', 'VBN'),
#   ('balance', 'NN'),
#   ('vietnamese', 'JJ'),
#   ('try', 'VB'),
#   ('vanilla', 'JJ'),
#   ('apricots', 'NNS'),
#   ('dry', 'JJ'),
#   ('thai', 'NN'),
#   ('dusty', 'JJ'),
#   ('asian', 'JJ'),
#   ('spices', 'NNS'),
#   ('burmese', 'JJ'),
#   ('fare', 'NN')],
#  [('flavors', 'NNS'),
#   ('supported', 'VBD'),
#   ('cherry', 'JJ'),
#   ('tea', 'NN'),
#   ('spice', 'NN'),
#   ('leads', 'VBZ'),
#   ('tobacco', 'RB'),
#   ('good', 'JJ'),
#   ('complexity', 'NN'),
#   ('earthy', 'JJ'),
#   ('red', 'JJ'),
#   ('berry', 'NN'),
#   ('ageable', 'JJ'),
#   ('tannins', 'NNS'),
#   ('intriguing', 'VBG'),
#   ('nose', 'JJ'),
#   ('mint', 'NN')],
#  [('power', 'NN'),
#   ('little', 'JJ'),
#   ('hard', 'JJ'),
#   ('nose', 'NN'),
#   ('berry', 'VBP'),
#   ('previous', 'JJ'),
#   ('years', 'NNS'),
#   ('go', 'VBP'),
#   ('less', 'RBR'),
#   ('generous', 'JJ'),
#   ('floral', 'JJ'),
#   ('scents', 'NNS'),
#   ('wine', 'VBP'),
#   ('honest', 'JJS'),
#   ('palate', 'NN'),
#   ('surrounded', 'VBD'),
#   ('cassis', 'NN'),
#   ('size', 'NN'),
#   ('also', 'RB'),
#   ('balance', 'NN'),
#   ('compared', 'VBN'),
#   ('tight', 'JJ'),
#   ('road', 'NN'),
#   ('flavors', 'NNS'),
#   ('tinged', 'VBD'),
#   ('still', 'RB'),
#   ('good', 'JJ'),
#   ('way', 'NN'),
#   ('coconut', 'NN'),
#   ('middle', 'NN'),
#   ('dill', 'NN'),
#   ('aromas', 'VBP'),
#   ('rise', 'NN'),
#   ('herbs', 'NN')],
#  [('rich', 'JJ'),
#   ('port', 'NN'),
#   ('dried', 'VBD'),
#   ('fruits', 'NNS'),
#   ('make', 'VBP'),
#   ('ripe', 'JJ'),
#   ('herbal', 'JJ'),
#   ('character', 'NN'),
#   ('soft', 'JJ'),
#   ('berry', 'NN'),
#   ('jelly', 'RB'),
#   ('taste', 'RB'),
#   ('attractive', 'JJ'),
#   ('blend', 'NN'),
#   ('concentrated', 'VBD'),
#   ('leaving', 'VBG'),
#   ('firmer', 'NN'),
#   ('structure', 'NN'),
#   ('aftertaste', 'NN'),
#   ('density', 'NN'),
#   ('sweet', 'JJ'),
#   ('fruit', 'NN'),
#   ('masks', 'NNS'),
#   ('sweetness', 'JJ'),
#   ('aromas', 'NNS')],
#  [('finish', 'JJ'),
#   ('soft', 'JJ'),
#   ('full', 'JJ'),
#   ('vibrant', 'NN'),
#   ('fruit', 'NN'),
#   ('typical', 'JJ'),
#   ('cloaked', 'VBD'),
#   ('lacking', 'VBG'),
#   ('nose', 'RB'),
#   ('textured', 'VBN'),
#   ('palate', 'NN'),
#   ('vanilla', 'NN'),
#   ('honey', 'NN'),
#   ('scents', 'NNS'),
#   ('attractive', 'JJ'),
#   ('hay', 'NN'),
#   ('bodied', 'VBD'),
#   ('lingers', 'NNS'),
#   ('variety', 'NN')],
#  [('light', 'JJ'),
#   ('pineapple', 'NNS'),
#   ('citrus', 'VBP'),
#   ('classic', 'JJ'),
#   ('quite', 'RB'),
#   ('different', 'JJ'),
#   ('acid', 'JJ'),
#   ('vintage', 'NN'),
#   ('stainless', 'NN'),
#   ('fermented', 'VBD'),
#   ('moderate', 'JJ'),
#   ('alcohol', 'NN'),
#   ('06', 'CD'),
#   ('made', 'VBD'),
#   ('finished', 'VBN'),
#   ('well', 'RB'),
#   ('fruit', 'RB'),
#   ('high', 'JJ'),
#   ('style', 'NN'),
#   ('strength', 'NN'),
#   ('mix', 'NN')],
#  [('cellar', 'NN'),
#   ('imported', 'VBD'),
#   ('wide', 'JJ'),
#   ('baked', 'VBD'),
#   ('rich', 'JJ'),
#   ('known', 'VBN'),
#   ('black', 'JJ'),
#   ('europvin', 'NN'),
#   ('finish', 'JJ'),
#   ('multiple', 'JJ'),
#   ('importers', 'NNS'),
#   ('including', 'VBG'),
#   ('michael', 'NN'),
#   ('skurnik', 'NN'),
#   ('wines', 'NNS'),
#   ('wine', 'VBP'),
#   ('drink', 'NN'),
#   ('may', 'MD'),
#   ('christopher', 'VB'),
#   ('cannan', 'NN'),
#   ('selection', 'NN'),
#   ('tannins', 'VBZ'),
#   ('cassis', 'JJ'),
#   ('flavors', 'NNS'),
#   ('mauro', 'VBP'),
#   ('improve', 'VB'),
#   ('lot', 'NN'),
#   ('2005', 'CD'),
#   ('seems', 'VBZ'),
#   ('soft', 'JJ'),
#   ('frankly', 'RB'),
#   ('structure', 'NN'),
#   ('mildly', 'RB'),
#   ('syrupy', 'JJ'),
#   ('palate', 'NN'),
#   ('huge', 'JJ'),
#   ('blackberry', 'NN'),
#   ('fruit', 'NN'),
#   ('aromas', 'VBZ'),
#   ('chunky', 'NN'),
#   ('always', 'RB'),
#   ('show', 'VBP'),
#   ('best', 'JJS'),
#   ('results', 'NNS')],
#  [('everything', 'NN'),
#   ('spicy', 'NN'),
#   ('vanilla', 'NN'),
#   ('flavors', 'NNS'),
#   ('good', 'JJ'),
#   ('price', 'NN'),
#   ('fine', 'NN'),
#   ('fried', 'VBD'),
#   ('chicken', 'JJ'),
#   ('spearmint', 'NN'),
#   ('savory', 'NN'),
#   ('citrus', 'NN'),
#   ('nice', 'JJ'),
#   ('crisp', 'NN'),
#   ('white', 'JJ'),
#   ('wine', 'NN'),
#   ('cantonese', 'NN'),
#   ('polished', 'VBD')],
#  [('leaving', 'VBG'),
#   ('soft', 'JJ'),
#   ('tannins', 'NNS'),
#   ('spicy', 'VBP'),
#   ('attractive', 'JJ'),
#   ('red', 'JJ'),
#   ('obviously', 'RB'),
#   ('new', 'JJ'),
#   ('wood', 'NN'),
#   ('use', 'NN'),
#   ('remarkably', 'RB'),
#   ('rich', 'JJ'),
#   ('black', 'JJ'),
#   ('berry', 'NN'),
#   ('fruit', 'NN'),
#   ('come', 'VBP'),
#   ('well', 'RB'),
#   ('mint', 'RB'),
#   ('judicious', 'JJ')],
#  [('talk', 'NN'),
#   ('ripe', 'NN'),
#   ('berries', 'NNS'),
#   ('duras', 'VBP'),
#   ('fer', 'VBP'),
#   ('servadou', 'JJ'),
#   ('truly', 'RB'),
#   ('local', 'JJ'),
#   ('pedigree', 'JJ'),
#   ('prunes', 'NNS'),
#   ('dry', 'JJ'),
#   ('landscape', 'NN'),
#   ('palate', 'NN'),
#   ('notes', 'NNS'),
#   ('wine', 'VBP'),
#   ('made', 'VBN'),
#   ('modern', 'JJ'),
#   ('style', 'NN'),
#   ('wild', 'VBP'),
#   ('heather', 'PRP$'),
#   ('prominent', 'JJ'),
#   ('new', 'JJ'),
#   ('wood', 'NN'),
#   ('syrah', 'NN'),
#   ('spice', 'NN'),
#   ('aromas', 'NN')],
#  [('mineral', 'JJ'),
#   ('chenin', 'NN'),
#   ('blanc', 'NN'),
#   ('giving', 'VBG'),
#   ('supported', 'VBD'),
#   ('sweet', 'JJ'),
#   ('melon', 'NN'),
#   ('flavors', 'NNS'),
#   ('apricot', 'VBP'),
#   ('fresh', 'JJ'),
#   ('currants', 'NNS'),
#   ('mark', 'NN'),
#   ('refreshing', 'VBG'),
#   ('finish', 'JJ'),
#   ('fine', 'JJ'),
#   ('spice', 'NN'),
#   ('surprisingly', 'RB'),
#   ('complex', 'JJ'),
#   ('structure', 'NN'),
#   ('richer', 'JJR'),
#   ('chardonnay', 'NN'),
#   ('delicious', 'JJ'),
#   ('wine', 'NN'),
#   ('contrasting', 'NN')],
#  [('soft', 'JJ'),
#   ('apricot', 'NNS'),
#   ('blossom', 'VBP'),
#   ('white', 'JJ'),
#   ('flowers', 'NNS'),
#   ('moving', 'VBG'),
#   ('towards', 'NNS'),
#   ('yellow', 'JJ'),
#   ('fruits', 'NNS'),
#   ('ripe', 'VBP'),
#   ('pink', 'VB'),
#   ('grapefruit', 'JJ'),
#   ('mineral', 'JJ'),
#   ('chalkiness', 'NN'),
#   ('edge', 'NN'),
#   ('enticingly', 'RB'),
#   ('perfumed', 'VBD'),
#   ('wine', 'JJ'),
#   ('rich', 'JJ'),
#   ('palate', 'NN')],
#  [('mineral', 'NN'),
#   ('would', 'MD'),
#   ('make', 'VB'),
#   ('broad', 'JJ'),
#   ('carricante', 'NN'),
#   ('mint', 'NN'),
#   ('stone', 'NN'),
#   ('fruit', 'NN'),
#   ('toasty', 'JJ'),
#   ('blend', 'NN'),
#   ('peach', 'NN'),
#   ('wine', 'NN'),
#   ('perfect', 'JJ'),
#   ('companion', 'NN'),
#   ('fragrant', 'NN'),
#   ('aromas', 'IN'),
#   ('almond', 'NN'),
#   ('edèlmio', 'NN'),
#   ('terms', 'NNS'),
#   ('swordfish', 'JJ'),
#   ('sophisticated', 'JJ'),
#   ('chardonnay', 'NN'),
#   ('mouthfeel', 'NN'),
#   ('roasted', 'VBD'),
#   ('eggplant', 'JJ'),
#   ('freshly', 'RB'),
#   ('chopped', 'VBD'),
#   ('pear', 'JJ'),
#   ('generous', 'JJ')],
#  [('supple', 'NN'),
#   ('feel', 'VBP'),
#   ('full', 'JJ'),
#   ('smoked', 'VBN'),
#   ('bacon', 'JJ'),
#   ('wine', 'NN'),
#   ('soft', 'JJ'),
#   ('concentration', 'NN'),
#   ('generous', 'JJ'),
#   ('mature', 'NN'),
#   ('blueberry', 'NN'),
#   ('bursting', 'VBG'),
#   ('aromas', 'NNS'),
#   ('pair', 'NN'),
#   ('lamb', 'VBP'),
#   ('syrah', 'NN'),
#   ('cherry', 'NN'),
#   ('spice', 'NN'),
#   ('roasted', 'VBD'),
#   ('pork', 'NN'),
#   ('round', 'NN')],
#  [('–', 'NN'),
#   ('2014', 'CD'),
#   ('support', 'NN'),
#   ('plummy', 'VBD'),
#   ('plenty', 'JJ'),
#   ('fresh', 'JJ'),
#   ('finish', 'NN'),
#   ('old', 'JJ'),
#   ('vineyards', 'NNS'),
#   ('throughout', 'IN'),
#   ('chocolaty', 'NN'),
#   ('fruit', 'NN'),
#   ('typical', 'JJ'),
#   ('barossa', 'NN'),
#   ('shiraz', 'NN'),
#   ('weight', 'VBD'),
#   ('crisp', 'JJ'),
#   ('drink', 'NN'),
#   ('creamy', 'NN'),
#   ('tannins', 'VBZ'),
#   ('spice', 'JJ'),
#   ('bit', 'NN'),
#   ('blended', 'JJ'),
#   ('complexity', 'NN'),
#   ('patchwork', 'NN')],
#  [('bit', 'NN'),
#   ('heavier', 'RBR'),
#   ('previous', 'JJ'),
#   ('vintage', 'NN'),
#   ('lingers', 'NNS'),
#   ('mouth', 'VBP'),
#   ('floral', 'JJ'),
#   ('character', 'NN'),
#   ('peach', 'NN'),
#   ('apple', 'NN'),
#   ('satisfying', 'VBG'),
#   ('finish', 'JJ'),
#   ('offers', 'NNS'),
#   ('equal', 'JJ'),
#   ('proportion', 'NN'),
#   ('instead', 'RB'),
#   ('pear', 'JJ'),
#   ('richness', 'NN'),
#   ('creamy', 'JJ'),
#   ('textural', 'JJ'),
#   ('wine', 'NN'),
#   ('mixes', 'NNS'),
#   ('fruit', 'NN'),
#   ('flavors', 'NNS'),
#   ('rich', 'VBP'),
#   ('less', 'JJR')],
#  [('fresh', 'JJ'),
#   ('finish', 'NN'),
#   ('apple', 'NN'),
#   ('key', 'JJ'),
#   ('lime', 'JJ'),
#   ('fruit', 'NN'),
#   ('flavors', 'NNS'),
#   ('hint', 'VBP'),
#   ('nice', 'JJ'),
#   ('mix', 'NN'),
#   ('minerality', 'NN'),
#   ('adds', 'VBZ'),
#   ('interest', 'NN'),
#   ('pear', 'NN'),
#   ('brings', 'VBZ'),
#   ('creamy', 'JJ'),
#   ('textural', 'JJ'),
#   ('pretty', 'NN')],
#  ...]

# %% [markdown]
# Only keep noun and adjective from the sentence

# %%
new_sentence_lst = []
temp = []
for sentence in taggedList:
    for word in sentence:
        if word[1] in ['NN','NNS','JJ','JJR']:
            temp.append(word[0])
    new_sentence_lst.append(temp)
    temp = []

# %% [markdown]
# Remove remaining stop words

# %%
stop_words = set(stopwords.words('english'))
Final_sentence_list = []
Final_sentence = []
for sentence in new_sentence_lst:
    for word in sentence:
        if(word not in stop_words):
            Final_sentence.append(word)
    Final_sentence_list.append(Final_sentence)
    Final_sentence = []

# %%
combined_sentence = []
for i in Final_sentence_list:
    combined_sentence.append(' '.join(i))

# %% [markdown]
# Use doc2vec and train the model

# %%
from nltk.tokenize import word_tokenize
from gensim.models.doc2vec import TaggedDocument
from gensim.models import Doc2Vec

tagged_data = [TaggedDocument(words=_d, tags=[str(i)]) for i, _d in enumerate(Final_sentence_list)]
max_epochs = 2000
vec_size = 600
alpha = 0.025

model = Doc2Vec(tagged_data,vector_size=vec_size,
                window=5,
                sample=1e-3,
                min_count=1,worker=4,negative=5)
model.train(tagged_data,total_examples=model.corpus_count,epochs=100)
model.save("d2v.model")
print("Model Saved")
# Out:
# Model Saved

# %% [markdown]
# Given a description using the same method to process the sentence

# %%
test = 'Aromas include tropical fruit, broom, brimstone and dried herb. The palate is not overly expressive, offering unripened apple, citrus and dried sage alongside brisk acidity.'
r = Rake()
# extracting the words by passing the text
r.extract_keywords_from_text(test)
# getting the dictionary whith key words as keys and their scores as values
key_words_dict_scores = r.get_word_degrees()
tagged_sentence = nltk.pos_tag(list(key_words_dict_scores.keys()))
test_sentence = []
for word in tagged_sentence:
    if word[1] in ['NN','NNS','JJ','JJR']:
        test_sentence.append(word[0])

# %% [markdown]
# Compute the similarity between test description vector to the existing description vectors and select wines with highest similarity score

# %%
model = Doc2Vec.load("d2v.model")
#to find the vector of a document which is not in training data
v1 = model.infer_vector(doc_words=test_sentence,alpha=0.0025,steps=5000)

# to find most similar doc using tags
similar_doc = model.docvecs.most_similar([v1],topn=10)
top_recommendation=[]
for count,similar in similar_doc:
    top_recommendation.append(df.title[int(count)])
    sentence=df.description[int(count)]
    words=''
    for  word in sentence:
        words=words+word+''
    print(words+' similartiy score: '+ str(similar))
# Out:
# Aromas include tropical fruit, broom, brimstone and dried herb. The palate isn't overly expressive, offering unripened apple, citrus and dried sage alongside brisk acidity. similartiy score: 0.7694101333618164
# Made entirely with native grape Zibibbo, this opens with aromas of sage, tangerine zest and Mediterranean herb. The aromas follow through to the lively palate alongside brisk acidity and a saline note. similartiy score: 0.36678361892700195
# Aromas of green apple, Bartlett pear, citrus and sage lead into the lightly sparkling palate. Fresh acidity lifts the rich flavors. similartiy score: 0.3343934714794159
# The nose on this isn't very expressive but the palate reveals crunchy Bartlett pear and yellow apple, while a hint of sage in the background adds interest. Brisk acidity gives it a zesty finish. similartiy score: 0.31226807832717896
# Subdued aromas of Spanish broom and brimstone float from the glass. The vertical palate offers yellow apple, citrus zest and mineral alongside crisp acidity. similartiy score: 0.3075248897075653
# Aromas suggesting nail polish remover, stewed plum, cellar floor and oak lead the nose. The evolved palate reflects the scorching vintage, offering raisin, powdered sage and balsamic notes alongside bracing grainy tannins and the heat of evident alcohol. Drink sooner rather than later. similartiy score: 0.2936597466468811
# Delicately scented, this opens with whiffs of white spring flower and orchard fruit. The crisp palate mirrors the nose, offering apple, pear and citrus, alongside bright acidity. A hint of wet stone wraps up the finish. similartiy score: 0.29240506887435913
# Aromas of almond, pressed white flower and crushed stone emerge on this racy white. The palate is less expressive, showing apple skin, mineral and a hint of citrus. It's on the lean side, with brisk acidity. similartiy score: 0.2846904397010803
# Red apple aromas are slightly overripe in nature, with citrus zest adding verve. The light-bodied palate is zippy and brisk, offering a fresh-pressed apple flavor. similartiy score: 0.2810960114002228
# Made with 60% Friulano and 40% Sauvignon, this has aromas of toast and citrus. The aromas carry over to the palate alongside notes of vanilla and chopped herb. Drink soon. similartiy score: 0.2788997292518616

# %%
print(f'Top 5 recommended wine based on description: {test}\n {top_recommendation[1:6]}')
# Out:
# Top 5 recommended wine based on description: Aromas include tropical fruit, broom, brimstone and dried herb. The palate is not overly expressive, offering unripened apple, citrus and dried sage alongside brisk acidity.
#  ['Coste Ghirlanda 2013 Silenzio Zibibbo (Terre Siciliane)', 'Valdo NV Cuvée Viviana  (Valdobbiadene Superiore di Cartizze)', 'Marilena Barbera 2013 Coste al Vento Grillo (Sicilia)', 'Contrada Santo Spirito di Passopisciaro 2012 Animalucente Bianco  (Etna)', 'Signae 2011  Montefalco Sagrantino']

# %% [markdown]
# ### Grape Recommendation based on common words in Description

# %% [markdown]
# Grape with more common words in description column will be recommended given the name of a grape variety

# %%
# Use cleaned wine dataset
data = pd.read_csv('clean_wine_dataset.csv')

# %%
data.head()
# Out:
#                                          description  \
# 0  Mac Watson honors the memory of a wine once ma...
# 1  This spent 20 months in 30% new French oak, an...
# 2  This is the top wine from La Bégude, named aft...
# 3  Deep, dense and pure from the opening bell, th...
# 4  Slightly gritty black-fruit aromas include a s...
#
#                      designation  points  price        province  \
# 0  Special Selected Late Harvest      96   90.0      California
# 1                        Reserve      96   65.0          Oregon
# 2                     La Brûlade      95   66.0        Provence
# 3                      Numanthia      95   73.0  Northern Spain
# 4                      San Román      95   65.0  Northern Spain
#
#               variety                winery
# 0     Sauvignon Blanc              Macauley
# 1          Pinot Noir                 Ponzi
# 2  Provence red blend  Domaine de la Bégude
# 3       Tinta de Toro             Numanthia
# 4       Tinta de Toro              Maurodos

# %%
# Create a new dataframe with only variety and description columns
df = data[['variety','description']]

# %%
df.shape
# Out:
# (152261, 2)

# %%
df.nunique()
# There are 735 unique grape varieties
# Out:
# variety           735
# description    152261
# dtype: int64

# %%
# Count the number of descriptions per variety
des_number = df['variety'].value_counts()
des_number
# Out:
# Pinot Noir                  15503
# Chardonnay                  14439
# Cabernet Sauvignon          12269
# Red Blend                   10317
# Sauvignon Blanc              6549
#                             ...
# Bobal-Cabernet Sauvignon        1
# Früburgunder                    1
# Kotsifali                       1
# Pied de Perdrix                 1
# Cesanese                        1
# Name: variety, Length: 735, dtype: int64

# %%
# Convert to Dataframe
df_des_number = pd.DataFrame({'variety':des_number.index, 'des_number':des_number.values})
df_des_number
# Out:
#                       variety  des_number
# 0                  Pinot Noir       15503
# 1                  Chardonnay       14439
# 2          Cabernet Sauvignon       12269
# 3                   Red Blend       10317
# 4             Sauvignon Blanc        6549
# ..                        ...         ...
# 730  Bobal-Cabernet Sauvignon           1
# 731              Früburgunder           1
# 732                 Kotsifali           1
# 733           Pied de Perdrix           1
# 734                  Cesanese           1
#
# [735 rows x 2 columns]

# %%
df_des_number[(df_des_number['des_number']>1)].shape
# Out of 735 grape varieties, 589 have more than one descriptions
# Out:
# (589, 2)

# %%
# Create a list of grape varieties that have more than one descriptions
multi_des = df_des_number[(df_des_number['des_number']>1)]['variety'].tolist()
len(multi_des)
# Out:
# 589

# %%
# Create a list of grape varieties that have only one description
one_des = df_des_number[(df_des_number['des_number']==1)]['variety'].tolist()
len(one_des)
# Out:
# 146

# %%
df.set_index('variety', inplace = True)

# %% [markdown]
# Extract common words from the descriptions of grape varieties that have more than one description

# %%
from sklearn.feature_extraction.text import TfidfTransformer, CountVectorizer

df1 = pd.DataFrame(columns=['variety','description'])

# Define a CountVectorizer object
cv = CountVectorizer(stop_words='english', ngram_range=(2,2))
# Define a TfidfTransformer object
tfidf_transformer = TfidfTransformer(smooth_idf=True, use_idf=True)

for grape in multi_des:
    
    df2 = df.loc[[grape]]
    # Generate word counts
    word_count_vector = cv.fit_transform(df2['description'])
    # Compute the IDF values
    tfidf_transformer.fit(word_count_vector)
    # Obtain top 100 common words (meaning low IDF values) used in the reviews
    df2_idf = pd.DataFrame(tfidf_transformer.idf_, index=cv.get_feature_names(), columns=["idf_weights"])
    df2_idf.sort_values(by=["idf_weights"], inplace=True)
    common_words = df2_idf.iloc[:100].index.tolist()
    # Convert the list to a string
    common_words_str = ", ".join(elem for elem in common_words)
    
    # Add the variety and its common words in descriptions to a new dataframe
    new_row = {'variety':grape, 'description':common_words_str}
    df1 = df1.append(new_row, ignore_index=True)

# %%
df1
# Out:
#                 variety                                        description
# 0            Pinot Noir  pinot noir, black cherry, cherry fruit, raspbe...
# 1            Chardonnay  buttered toast, tropical fruit, fruit flavors,...
# 2    Cabernet Sauvignon  black cherry, black currant, cabernet sauvigno...
# 3             Red Blend  cabernet sauvignon, black cherry, palate offer...
# 4       Sauvignon Blanc  sauvignon blanc, passion fruit, tropical fruit...
# ..                  ...                                                ...
# 584        Moscato Rosa  zest hint, hint cake, refreshing acidity, oran...
# 585             Sercial  acids long, old wood, perfumed spirits, price ...
# 586         Rara Neagra  ripe cherry, acidity pleasantly, lovely wine, ...
# 587          Chancellor  answer gamay, hold attention, hue example, iow...
# 588             Gouveio  15 rabigato, gouveio grape, grape known, green...
#
# [589 rows x 2 columns]

# %% [markdown]
# Remove stop words in descriptions of grape varieties that have only one description

# %%
stop_words = set(stopwords.words('english'))
df3 = pd.DataFrame(columns=['variety','description'])

for grape in one_des:
    df4 = df.loc[[grape]]
    for word in df4['description']:
        new_des = []
        if word not in stop_words:
            new_des.append(word)
    new_row = {'variety':grape, 'description':", ".join(elem for elem in new_des)}
    df3 = df3.append(new_row, ignore_index=True)

# %%
df3
# Out:
#                       variety  \
# 0     Moschofilero-Chardonnay
# 1               Shiraz-Merlot
# 2            Schwartzriesling
# 3                   Vidadillo
# 4                      Athiri
# ..                        ...
# 141  Bobal-Cabernet Sauvignon
# 142              Früburgunder
# 143                 Kotsifali
# 144           Pied de Perdrix
# 145                  Cesanese
#
#                                            description
# 0    This Moschofilero/Chardonnay blend feels a bit...
# 1    A ripe, juicy wine, layering red plums, rhubar...
# 2    Dark shades of bramble and smoked nuts lend a ...
# 3    The aromas of wet clay, mild chili peppers, ce...
# 4    Spice, citrus and minerals typify the nose and...
# ..                                                 ...
# 141  Mild, dusty cherry aromas set up a pulling, dr...
# 142  Quite rare in the U.S. market, this ripe richl...
# 143  A luscious nose of chocolate-covered cherries ...
# 144  Distantly related to Malbec, Pied de Perdrix i...
# 145  Made from old vines of Cesanese, this structur...
#
# [146 rows x 2 columns]

# %%
df1 = df1.set_index('variety')
df3 = df3.set_index('variety')

# %% [markdown]
# Combine varieties with more than one descriptions and only one description to a single dataframe

# %%
df1 = df1.append(df3,ignore_index=False)

# %%
df1
# Out:
#                                                                 description
# variety
# Pinot Noir                pinot noir, black cherry, cherry fruit, raspbe...
# Chardonnay                buttered toast, tropical fruit, fruit flavors,...
# Cabernet Sauvignon        black cherry, black currant, cabernet sauvigno...
# Red Blend                 cabernet sauvignon, black cherry, palate offer...
# Sauvignon Blanc           sauvignon blanc, passion fruit, tropical fruit...
# ...                                                                     ...
# Bobal-Cabernet Sauvignon  Mild, dusty cherry aromas set up a pulling, dr...
# Früburgunder              Quite rare in the U.S. market, this ripe richl...
# Kotsifali                 A luscious nose of chocolate-covered cherries ...
# Pied de Perdrix           Distantly related to Malbec, Pied de Perdrix i...
# Cesanese                  Made from old vines of Cesanese, this structur...
#
# [735 rows x 1 columns]

# %%
# instantiating and generating the count matrix
count = CountVectorizer()
count_matrix = count.fit_transform(df1['description'])

# %%
indices = pd.Series(df1.index)
indices[:5]
# Out:
# 0            Pinot Noir
# 1            Chardonnay
# 2    Cabernet Sauvignon
# 3             Red Blend
# 4       Sauvignon Blanc
# Name: variety, dtype: object

# %%
count_matrix.shape
# Out:
# (735, 6056)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# generating the cosine similarity matrix
cosine_sim = cosine_similarity(count_matrix, count_matrix)
cosine_sim
# Out:
# array([[1.        , 0.43112132, 0.72809609, ..., 0.246641  , 0.20387964,
#         0.23927691],
#        [0.43112132, 1.        , 0.46545866, ..., 0.16926637, 0.18755211,
#         0.03493883],
#        [0.72809609, 0.46545866, 1.        , ..., 0.25313204, 0.1727615 ,
#         0.13380643],
#        ...,
#        [0.246641  , 0.16926637, 0.25313204, ..., 1.        , 0.37032804,
#         0.35571892],
#        [0.20387964, 0.18755211, 0.1727615 , ..., 0.37032804, 1.        ,
#         0.26196842],
#        [0.23927691, 0.03493883, 0.13380643, ..., 0.35571892, 0.26196842,
#         1.        ]])

# %%
df1 = df1.reset_index()

# %%
def recommendations(variety_input, cosine_sim=cosine_sim):
    
    # Get the index of the input variety
    idx = indices[indices == variety_input].index[0]
    
    # Get and sort the pairwise similarity scores between the input variety and all the varieties
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    # Top 5 similarity scores and their corresponding variety indices
    sim_scores = sim_scores[1:6]
    variety_idx_list = [i[0] for i in sim_scores]
     
    # Create the output dataframe
    df_output = pd.DataFrame(columns=['Recommended Grape Varieties', 'Similarity Score', 'Top 7 Common Words'])
    
    for i in sim_scores: 
        # i[0] is the index of the variety
        variety_name = df1.iloc[i[0]]['variety']
        # Get top 7 common words in descriptions
        des = df1.iloc[i[0]]['description']
        # If in the variety list that have more than one descriptions
        if variety_name in multi_des:   
            des_split = des.split(',')
            key_words_list = des_split[:7]
            key_words_str = ', '.join(key_words_list)
        # If in the variety list that have only one description
        else:
            key_words_str = des
            
        new_row = {'Recommended Grape Varieties':variety_name,'Similarity Score':i[1],'Top 7 Common Words':key_words_str}
        df_output = df_output.append(new_row, ignore_index=True)
    
    df_output.set_index('Recommended Grape Varieties') 
    pd.set_option('max_colwidth', 500)
   
    return df_output

# %% [markdown]
# Examples:

# %%
recommendations('Red Blend')
# Out:
#   Recommended Grape Varieties  Similarity Score  \
# 0                  Sangiovese          0.833785
# 1                     Barbera          0.804758
# 2                   Aglianico          0.778970
# 3   Cabernet Sauvignon-Merlot          0.775810
# 4              Cabernet Franc          0.757077
#
#                                                                                                       Top 7 Common Words
# 0              black cherry,  palate offers,  palate delivers,  lead nose,  grained tannins,  blue flower,  white pepper
# 1           black cherry,  palate offers,  barbera alba,  fruit flavors,  palate doles,  skinned berry,  grained tannins
# 2               black cherry,  palate offers,  black fruit,  blue flower,  palate delivers,  black pepper,  opens aromas
# 3  cabernet sauvignon,  sauvignon merlot,  black cherry,  merlot blend,  blend cabernet,  cabernet merlot,  finish drink
# 4                cabernet franc,  cab franc,  black cherry,  fruit flavors,  cherry flavors,  medium bodied,  red cherry

# %%
recommendations('Pinot Noir')
# Out:
#   Recommended Grape Varieties  Similarity Score  \
# 0                      Merlot          0.886208
# 1                    Grenache          0.882202
# 2              Cabernet Franc          0.879778
# 3                   Zinfandel          0.766121
# 4                   Mourvèdre          0.764160
#
#                                                                                               Top 7 Common Words
# 0  black cherry,  fruit flavors,  cherry flavors,  red fruit,  cherry fruit,  medium bodied,  cabernet sauvignon
# 1            cherry fruit,  red fruit,  fruit flavors,  red cherry,  black cherry,  white pepper,  nose bottling
# 2        cabernet franc,  cab franc,  black cherry,  fruit flavors,  cherry flavors,  medium bodied,  red cherry
# 3            high alcohol,  black pepper,  spice flavors,  petite sirah,  wild berry,  fruit flavors,  dry creek
# 4         black pepper,  black cherry,  fruit flavors,  white pepper,  medium bodied,  black plum,  100 varietal
